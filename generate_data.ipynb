# %% [markdown]
# ### Building the dataset
#
# When creating a neural network to play chess, one of the fundamental steps is to build a comprehensive dataset that comprises chess board positions and corresponding moves. This dataset can be utilized to train the neural network to predict the optimal move for a given position.
#
# To build the dataset, one can use a chess engine to produce numerous chess games and document the board positions and moves executed in each game. A Python chess library such as python-chess can help in achieving this objective.
#
# Upon acquiring the dataset, the data must be preprocessed to ready it for use in training the neural network. This process may involve converting the board positions into a format that the neural network can interpret, such as a tensor or a flattened vector. Additionally, one-hot encoding can be employed to represent the moves as categorical variables.
#
# The primary objective of building a neural network is to establish multiple examples of the independent variable "x," which encodes the board-state, and the dependent outputs "y_policy" and "y_value_head." The former suggests the optimal move for the current player, while the latter indicates the present evaluation of the position (-1 for black win, +1 for white win, and any value in between for ongoing games). This evaluation can be thought of as the stockfish eval bar, which is commonly used.
#
# This Jupyter Notebook offers different approaches for generating training data that can be used to train a neural network using several techniques.

# %% [markdown]
# ### 1st approach: Get publicly available lichess data.
#
#  If you're interested in downloading an official torrent that contains records of all standard games played in a month on lichess, you can join the website https://database.lichess.org/. These records typically include around 100 million games, with almost 6% (for December 2022) of them having been analyzed by Stockfish. The Stockfish evaluation for each move is also appended as a comment on the game's mainlines. In order to create our dataset, we only choose games that have been analyzed by Stockfish, meaning that they include Stockfish evaluations as well.

# %%
import nbimporter
from Board_to_NeuralNetwork import board_to_network_input
from Board_to_NeuralNetwork import all_possible_moves
from MCTS_and_selfplay import choose_files_with_pattern
import numpy as np
import chess


possible_moves=all_possible_moves()

# %% [markdown]
# This code defines a function separate_evaluated_games() that reads in a PGN (Portable Game Notation) file containing chess games and writes out only those games that contain an "eval" annotation to a new PGN file. The purpose of this function is to extract a subset of evaluated games from a larger PGN file for further analysis.
#
# ### 4 Vito
#
#
# Maybe you could make it possible to look only at games which are played between players above 2k elo?

# %%
import chess
import chess.pgn

def separate_evaluated_games(max_eval_games=10):
    # Path to input PGN file
    file = r'C:\\Users\\45819\\Downloads\\lichess_db_standard_rated_2022-12.pgn'
    
    # Counters for evaluated games and total games
    num_eval_games = 0
    num_total_games = 0
    
    # Open the input PGN file for reading
    with open(file, "r") as input_file:
        # Read games one by one from the input file until there are no more games or the max number of evaluated games is reached
        while True and num_eval_games < max_eval_games:
            # Read in the next game from the input file using the chess.pgn module
            pgn = chess.pgn.read_game(input_file)
            num_total_games += 1
            
            # If there are no more games to read, break out of the loop
            if pgn is None:
                break
            
            # Convert the game to a string with header, moves, and evaluations
            pgn_string = pgn.accept(chess.pgn.StringExporter(headers=True, variations=False, comments=True))
            
            # If the game contains an "eval" annotation which means that it has been analyzed by stockfish,
            #write it to the output file and increment the counter
            if 'eval' in pgn_string:
                num_eval_games += 1
                if num_eval_games % 10000 == 1:
                    print('Found %d games with eval from a total of %d games.' % (num_eval_games, num_total_games))
                
                # Open the output file for writing and write the game to it
                with open("output.pgn", "a") as output_file:
                    pgn_string = '\n' + pgn_string + '\n'
                    output_file.write(pgn_string)

    # Return 0 as a placeholder value
    return 0

# Uncomment the following line to call the function and extract evaluated games from the input PGN file
# separate_evaluated_games(max_eval_games=1000000)

# %% [markdown]
# This code defines a function called create_training_data_from_evaluated_games which reads and processes evaluated chess games stored in a PGN file (output.pgn) to create training data for a neural network to learn how to play chess. The function starts by importing necessary modules such as chess.pgn, re, and numpy. It then initializes containers for storing the training data including chess board positions, best moves played, probability of best move, and evaluation of board position. The function iterates through a maximum number of games specified by max_num_games and for each game, it reads game data from the PGN file and stores moves and evaluations from the game. The evaluation of each position is obtained from Stockfish and the board position, best move played, and probability vector are stored in the initialized containers. The evaluation scores are normalized to a range of (-1, 1) before being stored. If the game ended due to time-out, it is skipped. Finally, the output data is transformed to numpy arrays and saved in separate files.

# %%
import chess.pgn
import re
import numpy as np

# Function to create training data from evaluated chess games
def create_training_data_from_evaluated_games(max_num_games=25000):
    
    # Open the PGN file containing the evaluated games
    pgn = open("output.pgn")
    
    # Get the string of all possible moves using a separate function all_possible_moves()
    possible_moves = all_possible_moves()
    
    # Initialize containers for training data
    positions = [] # chess board positions
    best_moves = [] # best moves played
    best_moves_probs = [] # probability of best move
    outcomes = [] # evaluation of board position
    
    # Loop through a maximum number of games to create training data from each game
    for _ in range(max_num_games):
        
        # Read a game from the PGN file
        game = chess.pgn.read_game(pgn)
        
        # Print progress after every 100 games
        if _ % 100 == 0:
            print(_ / max_num_games * 100, '%%')
        
        # Access the game result to determine the winner
        result = game.headers["Result"]
        
        # Check how the game terminated
        mode = game.headers.get("Termination")
        
        # If the game ended normally (checkmate or draw and not due to time out)
        if mode == 'Normal':
            
            # Initialize the chess board
            board = chess.Board()
            
            # Store all moves and evaluations from the games
            moves = [str(move) for move in game.mainline_moves()]
            evals = [str(boards.eval()) for boards in game.mainline()]

            # Iteratively go through every move of the game and save training data from it
            for i, m in enumerate(moves):
                
                # Get the evaluation of the current position from Stockfish
                evaluation = evals[i]
                
                # If the game has already ended in a checkmate
                if board.is_checkmate():
                    print('board is checkmate')
                    break
                
                # If Stockfish predicts checkmate in a few moves, convert it to a float32 score
                elif '#+' in evaluation:
                    moves_to_checkmate = re.findall(r'\d+', evaluation)
                    temp = 10000. - float(100 * int(moves_to_checkmate[0]))
                elif '#-' in evaluation:
                    moves_to_checkmate = re.findall(r'\d+', evaluation)
                    temp = -10000. + float(100 * int(moves_to_checkmate[0]))
                
                # Otherwise, append the evaluation as is
                elif evaluation == 'None':
                    break
                else:
                    temp = float(evaluation)
                
                # Normalize the evaluation score to a range of (-1, 1)
                temp /= 10000    
                outcomes.append(temp)
                
                # Store the current chess board position as input
                positions.append(board_to_network_input(board))
                
                # Store the current move played as best move
                best_moves.append(m)
                
                # Convert the best move to a probability vector with 0 on all other elements and 1 on played move
                # The purpose of this initialization is to train the neural network to play like a human,
                idx = np.where(possible_moves == m)
                probs = np.zeros_like(possible_moves, dtype=np.float32)
                probs[idx] = 1.
                
                # Update the move probabilities
                best_moves_probs.append(probs)

                # Create a move object that python-chess recognises and update the board with that move
                move = chess.Move.from_uci(m)
                board.push(move)

        # If the game ended due to time out, skip it
        elif mode =='Time forfeit':
    #         print('noob got flagged\n ')
            continue

    # Close the file
    pgn.close()


    # Transform output data to numpy arrays

    positions=np.array(positions)
    best_moves=np.array(best_moves)
    best_moves_probs=np.array(best_moves_probs)
    outcomes=np.array(outcomes)
    np.save('SL_boards%0.e'% (max_num_games), positions)
    np.save('SL_best_moves%0.e' %max_num_games, best_moves)
    np.save('SL_best_moves_probs%0.e'% (max_num_games), best_moves_probs)
    np.save('outcomes%0.e' %max_num_games, outcomes)

# %% [markdown]
# ### Generating a Dataset for Chess AI Training: Approach 2
# In this approach, we generate a number of chess positions by randomly sequencing moves and then ask Stockfish for the best move and evaluation for each position. While this method can create a dataset, it has two important drawbacks:
#
# 1. The chess positions generated from a random sequence of moves may not be representative of positions that naturally arise on the board through regular gameplay.
# 2. The optimal move and evaluation calculations performed by Stockfish can be time-consuming and create a bottleneck in the dataset creation process.
# Due to these reasons, this method may not be the most effective for creating a dataset for neural network training. However, it can be useful for generating end-game positions, which are typically the weakness of policy head decisions.
#
# To facilitate various chess-related tasks using the Stockfish engine, we have provided two functions: stockfish() and stockfish_best_move().
#
# The stockfish() function takes a chess board position represented by a chess.Board() object and analyzes it using the Stockfish chess engine to obtain an assessment of the game's score for the current board position, measured in centipawns (100 centipawns ~ 1 pawn). The evaluation score generated by the Stockfish engine ranges from -10000 to +10000 centipawns.
#
# The function can be called with the following parameters:
#
# board: a chess.Board() object representing the chess board position.
# depth: the maximum search depth that the Stockfish engine will use to analyze the board. If None, the engine will analyze the position until a final score is obtained.
# time_limit: the maximum amount of time in seconds that the Stockfish engine will use to analyze the board. If None, the engine will analyze the position until a final score is obtained. The user can choose to use either depth or time_limit, but not both.
# The stockfish_best_move() function also takes a chess board position represented by a chess.Board() object and uses the Stockfish engine to find the best move for the current board position. The function can be called with the following parameters:
#
# board: a chess.Board() object representing the chess board position.
# time_limit: the maximum amount of time in seconds that the Stockfish engine will use to find the best move for the current board position. The default value is 1.0.
# Note that these functions rely on a specific path to the Stockfish executable (r'C:\Users\45819\Downloads\chess\stockfish_15\stockfish_15_x64.exe'), which may not be compatible with your system. You may need to adjust the path based on the location of the Stockfish engine on your system. If you do not have Stockfish installed, you can download it from the official website at https://stockfishchess.org/download/windows/.
#
#
#
# The stockfish_best_move() function takes a chess board position and uses the Stockfish engine to find the best move for the current board position. The function can be called with the following parameters:
#
# board: a chess board position represented by a chess.Board() object.
# time_limit: the maximum amount of time in seconds that the Stockfish engine will use to find the best move for the current board position. The default value is 1.0.
# Upon execution, the stockfish_best_move() function opens the Stockfish engine, finds the best move for the current board position, prints it, and closes the engine. The function returns the best move as a chess.Move() object.
#
# Note that these functions are dependent on a specific path to the Stockfish executable (r'C:\Users\45819\Downloads\chess\stockfish_15\stockfish_15_x64.exe') which may not be compatible with your system. As such, you may need to adjust the path accordingly based on the location of the Stockfish engine on your system. If you do not have Stockfish installed on your system, you can download it from the official website at https://stockfishchess.org/download/windows/.

# %%
import random
import chess
import chess.engine
def stockfish(board, depth=None,time_limit=None): 
    file_name = r'C:\Users\45819\Downloads\chess\stockfish_15\stockfish_15_x64.exe'
    with chess.engine.SimpleEngine.popen_uci(file_name) as sf: # Start the chess engine
        if time_limit==None:
            result = sf.analyse(board, chess.engine.Limit(depth=depth)) # Analyze the position
            score1 = result['score'].white().score() # Get the score for the position from white's perspective
        elif depth==None:
            result = sf.analyse(board, chess.engine.Limit(time=time_limit)) # Analyze the position
            score1 = result['score'].white().score() # Get the score for the position from white's perspective
    return (score1)
    
def stockfish_best_move(board,time_limit=1.):
    file_name = r'C:\Users\45819\Downloads\chess\stockfish_15\stockfish_15_x64.exe'
    # Create a chess board
#     board = chess.Board()

    # Start the chess engine
    engine = chess.engine.SimpleEngine.popen_uci(file_name)

    # Find the best move for the current board position
    result = engine.play(board, chess.engine.Limit(time=time_limit))

    # Print the best move
    print("Best move:", result.move)

    # Close the engine
    engine.quit()
    return result.move

# %% [markdown]
# The function random_board(max_depth=200) generates a random chess board position by making a random sequence of legal moves on a new chess board. The function can be called with the following parameter:
#
# max_depth: the maximum number of moves to make. A random number of moves between 0 and max_depth is generated.
# The function works as follows:
#
# It starts by creating a new chess board object using chess.Board().
# It then generates a random number of moves between 0 and max_depth using random.randrange(0, max_depth).
# Next, it enters a loop that iterates depth times, where depth is the random number of moves generated in the previous step.
# In each iteration of the loop, it gets a list of all legal moves using board.legal_moves, chooses a random move from the list using random.choice(all_moves), applies the chosen move to the board using board.push(random_move), and checks if the game is over using board.is_game_over().
# If the game is over, the function stops making moves and returns the final board position using return board.
# If the game is not over, the function continues making moves until it has made the specified number of moves or until the game is over.

# %%
# Define a function that creates a random chess board by making a random number of legal moves
def random_board(max_depth=200):
    board = chess.Board() # Create a new chess board
    depth = random.randrange(0, max_depth) # Generate a random number of moves to make

    # Make the specified number of moves
    for _ in range(depth):
        all_moves = list(board.legal_moves) # Get a list of all legal moves
        random_move = random.choice(all_moves) # Choose a random move from the list
        board.push(random_move) # Apply the move to the board
        if board.is_game_over(): # If the game is over, stop making moves
            break

    return board # Return the final board

# %%
# Create a chess board object
def set_network_probs(board,move):
    idx=np.where(possible_moves==move) #Find the indexes of legal moves
    probs=np.zeros_like(possible_moves,dtype=np.float32) # Initialize the policy head
    probs[idx]=1. # Set a probability of 1 for the move suggested by stockfish, and 0 for all other moves
    # Return the move probabilities.
    return probs

# %%
# A function which returns the material remaining on board for white and black:

def material(board):
    # Define a dictionary of piece values
    piece_values = {
        chess.PAWN: 1,
        chess.KNIGHT: 3,
        chess.BISHOP: 3,
        chess.ROOK: 5,
        chess.QUEEN: 9,
        chess.KING: 0
    }

    # Initialize variables to store material values
    white_material = 0
    black_material = 0

    # Get a dictionary of all the pieces on the board along with their positions
    piece_map = board.piece_map()

    # Iterate through the dictionary to calculate total material for each color
    for square, piece in piece_map.items():
        if piece.color == chess.WHITE:
            white_material += piece_values.get(piece.piece_type, 0)
        else:
            black_material += piece_values.get(piece.piece_type, 0)

    return white_material,black_material

# %% [markdown]
# ### Time to create some endgame positions
#
# The reasons for making this dataset is that the neural network is failing to make solid choices in the end-game. Therefore we supply it with more examples of endgame positions data and best moves to cover better the parameter-space of the input data(positions).
# This function creates an endgame dataset by generating random chess board positions and collecting their corresponding stockfish evaluations and best moves. It saves the resulting dataset as numpy arrays in separate files for the inputs, evaluations, and move probabilities.

# %%
import numpy as np

# This function generates a dataset of chess endgame positions, their evaluations, and move probabilities
def create_endgame_dataset(N_dataset, time_limit):
    # Initialize empty lists to store inputs (x), evaluations (y1), and move probabilities (y2)
    x=[]
    y1=[]
    y2=[]
    
    # Initialize a counter variable for the number of generated positions
    i=0
    
    # Loop until the desired number of positions is generated
    while i < N_dataset:
        # Generate a random chess board with a maximum depth of 600
        board = random_board(max_depth=600)
        
        # Calculate the material score for both players
        wm, bm = material(board)
        
        # Only consider positions where the total material on the board is less than 40 (endgame)
        if wm + bm < 40:
            try:
                # Print the progress of generating the dataset every 10 saved positions
                if i % 10 == 0:
                    print(i * 100 / N_dataset, '%% progress')
                
                # Evaluate the board using Stockfish and store the score
                score = stockfish(board, time_limit=time_limit, stockfish_mode='one player')
                
                # Get the best move for the current board
                best_move = stockfish_best_move(board, time_limit=time_limit)
                
                # Normalize the score by dividing it by 10000 and append the input, evaluation, and move probabilities to their respective lists
                saved_score = float(score) / 10000
                x.append(board_to_network_input(board))
                y1.append(saved_score)
                y2.append(set_network_probs(board, str(best_move)))
                
                # Increment the position counter
                i += 1
                
                # Save the current dataset as numpy arrays in separate files for the inputs, evaluations, and move probabilities
                num_output = len(choose_files_with_pattern(max_num=9999999, pickles_path='./endgame_data/positions*')) + 1
                formatted_string = "{:06d}".format(num_output)
                string1 = r'C:\Users\45819\Downloads\chess\chess\endgame_data\positions_' + formatted_string
                string2 = r'C:\Users\45819\Downloads\chess\chess\endgame_data\evaluations_' + formatted_string
                string3 = r'C:\Users\45819\Downloads\chess\chess\endgame_data\move_probs_' + formatted_string
                np.save(string1, x)
                np.save(string2, y1)
                np.save(string3, y2)
                
                # Clear the input, evaluation, and move probability lists
                x = []
                y1 = []
                y2 = []
            except Exception as e:
                # If an error occurs, print the error message and continue generating positions
                print(f"An error occurred: {e}")
                print('whoops!')
                continue
    
    # Return the inputs, evaluations, and move probabilities for the generated positions
    return x, y1, y2

# Example usage of the function
# x, y1, y2 = create_endgame_dataset(N_dataset=1, time_limit=0.25)
# print(np.shape(x), np.shape(y1), np.shape(y2))

# %% [markdown]
#  Note that the user sets a maximum number of positions and a time limit for the stockfish evaluation for each of  these positions, but the code saves incrementally the positions in seperate files. This is of particular use when the time of the calculation has been underestimated, and the ending needs to stop without having saved any position. In order to pass this data to the neural netwrok it is somewhat convenient to consolidate this dataset which is split among manydata to a single data file. For this reason the next cell uses some basic np functions in order to stack the position arrays in a single array

# %%
###### import time
import numpy as np

# Set the maximum number of files to process
n = 2

# Get a list of file names that match a specific pattern in the directory
position_names = choose_files_with_pattern(max_num=n, pickles_path='./endgame_data/positions*')

# Sort the file names in alphabetical order
names = sorted(position_names)

# Generate the names of the corresponding evaluation and move probability files
evaluation_names = [string.replace("positions", "evaluations") for string in names]
moves_probs_names = [string.replace("positions", "move_probs") for string in names]

# Load the position, move probability, and evaluation arrays from the files
positions_s = [np.load(position_names[i]) for i in range(len(position_names))]
move_probs = [np.load(moves_probs_names[i]) for i in range(len(moves_probs_names))]
evaluations = [np.load(evaluation_names[i]) for i in range(len(evaluation_names))]

# Stack the position arrays into a single array
positions = np.stack(positions_s)
move_probs=np.stack(move_probs)
evaluations=np.stack(evaluations)

#Squeeze the unnecessary dimension
positions=np.squeeze(positions,axis=1)
evaluations=np.squeeze(evaluations,axis=1)
move_probs=np.squeeze(move_probs,axis=1)


# Uncomment this line to save the end-game data.
# np.save('final_endgame_pos',positions)
# np.save('final_endgame_move_probs',move_probs)
# np.save('final_endgame_evaluations',evaluations)

# %% [markdown]
# ### 3rd approach: Create a dataset through chess puzzles!
#
# The third option is a nice alternative to the previous cumbersome computationally approach. Here lichess savees us once again , since htey host a torrent which contains  3 milion chess puzzles along with their solutions. This can be found in https://database.lichess.org/#puzzles and downloaded as a CSV file which is read in the lines below. The general idea of this approach is to build a dataset which does not contain of predicted position evaluation, but only the policy head, the optimal move for each position.

# %%
#Load the data from the CSV file:

import csv

puzzle_ids=[]
fens=[]
ratings=[]
moves_solution=[]
games_url=[]
j=0
with open( r'C:\\Users\\45819\\Downloads\\lichess_db_puzzle.csv', "r") as file:
    reader = csv.reader(file)
    for row in reader:
        puzzle_id = row[0]
        puzzle_ids.append(puzzle_id)
        j+=1
        fen = row[1]
        fens.append(fen)
        
        moves = row[2]
        moves_solution.append(moves)
        
        rating = row[3]
        ratings.append(rating)
        rating_deviation = row[4]
        popularity = row[5]
        nb_plays = row[6]
        themes = row[7]
        game_url = row[8]
        games_url.append(game_url)
        opening_family = row[9]
        
print(j,' chess puzzles found')
# Out:
# 3080529

# %%
# Save the data in a neural network friendly way:
import chess
import time
import numpy as np

t0=time.time()
x=[]
y_policy=[]
N_puzzles=500000
for i in range(1,N_puzzles):
    if i%100==0:
        t2=time.time()
        remaining=N_puzzles-i
        puzz_p_s=i/(t2-t0)
        t=remaining/puzz_p_s
        hours = t // 3600
        remaining_seconds = t % 3600
        minutes = remaining_seconds // 60
        seconds = remaining_seconds % 60
        print(f"{hours} hour(s), {minutes} minute(s), and {seconds} second(s).")
    fen=fens[i]
    moves=moves_solution[i]
    rating=ratings[i]
    game_url=games_url[i]
#     print(game_url)
#     print(moves)
#     print(' This puzzle has a rating of ',rating)

    board=chess.Board()
    board.set_fen(fen)
#     print('starting board:\n',board)
    for j,move in enumerate(moves.split()):
#         print(board)
#         print(move)

        if j>0:
            x.append(board_to_network_input(board))
#             print('saving board: \n',board)
#             print('saving move:',move)
            probs=set_network_probs(board,move)
            y_policy.append(probs)
            
        move_uci=chess.Move.from_uci(move)
        board.push(move_uci)

x=np.array(x)
y=np.array(y_policy)

print(np.shape(x))
# .
print(np.shape(y))
np.save('x_puzzles1m',x)
np.save('y_puzzles1m',y)
# Out:
# 2.0 hour(s), 2.0 minute(s), and 16.0502347946167 second(s).
# 1.0 hour(s), 55.0 minute(s), and 17.356242656706854 second(s).
# 1.0 hour(s), 53.0 minute(s), and 44.80323529243378 second(s).
# 1.0 hour(s), 53.0 minute(s), and 25.36608648300171 second(s).
# 1.0 hour(s), 52.0 minute(s), and 48.163644790650324 second(s).
# 1.0 hour(s), 53.0 minute(s), and 9.576225360234275 second(s).
# 1.0 hour(s), 53.0 minute(s), and 0.9147597721648708 second(s).
# 1.0 hour(s), 51.0 minute(s), and 58.491485595703125 second(s).
# 1.0 hour(s), 52.0 minute(s), and 24.59758196936764 second(s).
# 1.0 hour(s), 52.0 minute(s), and 19.729464292526245 second(s).
# 1.0 hour(s), 52.0 minute(s), and 45.01139213822171 second(s).
# 1.0 hour(s), 53.0 minute(s), and 45.371468623479814 second(s).
# 1.0 hour(s), 53.0 minute(s), and 21.720283031463623 second(s).
# 1.0 hour(s), 53.0 minute(s), and 52.23837835448194 second(s).
# 1.0 hour(s), 53.0 minute(s), and 40.2382672627773 second(s).
# 1.0 hour(s), 53.0 minute(s), and 43.913697600364685 second(s).
# 1.0 hour(s), 54.0 minute(s), and 1.3706093535702166 second(s).
# 1.0 hour(s), 53.0 minute(s), and 58.9976937505935 second(s).
# 1.0 hour(s), 53.0 minute(s), and 49.38284188822672 second(s).
# 1.0 hour(s), 53.0 minute(s), and 49.06957697868256 second(s).
# 1.0 hour(s), 54.0 minute(s), and 2.8945995398926243 second(s).
# 1.0 hour(s), 54.0 minute(s), and 18.50335283712866 second(s).
# 1.0 hour(s), 54.0 minute(s), and 17.2499189895143 second(s).
# 1.0 hour(s), 54.0 minute(s), and 42.75816599528025 second(s).
# 1.0 hour(s), 54.0 minute(s), and 47.978538036346436 second(s).
# 1.0 hour(s), 54.0 minute(s), and 42.34776020050049 second(s).
# 1.0 hour(s), 54.0 minute(s), and 31.41504500530391 second(s).
# 1.0 hour(s), 54.0 minute(s), and 27.830872297286987 second(s).
# 1.0 hour(s), 54.0 minute(s), and 46.87440002375661 second(s).
# 1.0 hour(s), 54.0 minute(s), and 54.10110481580159 second(s).
# 1.0 hour(s), 54.0 minute(s), and 49.54015421098302 second(s).
# 1.0 hour(s), 55.0 minute(s), and 5.068500280380249 second(s).
# 1.0 hour(s), 55.0 minute(s), and 9.771954037925752 second(s).
# 1.0 hour(s), 55.0 minute(s), and 20.693728615255168 second(s).
# 1.0 hour(s), 55.0 minute(s), and 25.369246244430542 second(s).
# 1.0 hour(s), 55.0 minute(s), and 19.906474855210945 second(s).
# 1.0 hour(s), 55.0 minute(s), and 6.205947173608365 second(s).
# 1.0 hour(s), 55.0 minute(s), and 26.547789008993277 second(s).
# 1.0 hour(s), 55.0 minute(s), and 22.66085322697927 second(s).
# 1.0 hour(s), 55.0 minute(s), and 29.07732391357422 second(s).
# 1.0 hour(s), 55.0 minute(s), and 21.428882290677393 second(s).
# 1.0 hour(s), 55.0 minute(s), and 14.790287903377248 second(s).
# 1.0 hour(s), 55.0 minute(s), and 14.051622667978336 second(s).
# 1.0 hour(s), 55.0 minute(s), and 5.7285196130924305 second(s).
# 1.0 hour(s), 54.0 minute(s), and 51.87438691986972 second(s).
# 1.0 hour(s), 54.0 minute(s), and 53.227795497230545 second(s).
# 1.0 hour(s), 54.0 minute(s), and 46.4471016031639 second(s).
# 1.0 hour(s), 54.0 minute(s), and 43.09373100598714 second(s).
# 1.0 hour(s), 54.0 minute(s), and 43.766287842575366 second(s).
# 1.0 hour(s), 54.0 minute(s), and 43.06666159629822 second(s).
# 1.0 hour(s), 54.0 minute(s), and 38.93998406915034 second(s).
# 1.0 hour(s), 54.0 minute(s), and 39.301537403694056 second(s).
# 1.0 hour(s), 54.0 minute(s), and 42.68009078277828 second(s).
# 1.0 hour(s), 54.0 minute(s), and 34.78553900012321 second(s).
# 1.0 hour(s), 54.0 minute(s), and 36.400734749707226 second(s).
# 1.0 hour(s), 54.0 minute(s), and 35.16687767846179 second(s).
# 1.0 hour(s), 54.0 minute(s), and 38.35555016367107 second(s).
# 1.0 hour(s), 54.0 minute(s), and 37.20494715098721 second(s).
# 1.0 hour(s), 54.0 minute(s), and 34.45299036219967 second(s).
# 1.0 hour(s), 54.0 minute(s), and 32.03594994544892 second(s).
# 1.0 hour(s), 54.0 minute(s), and 29.77433267186916 second(s).
# 1.0 hour(s), 54.0 minute(s), and 29.13520343842083 second(s).
# 1.0 hour(s), 54.0 minute(s), and 21.25540717442891 second(s).
# 1.0 hour(s), 54.0 minute(s), and 17.363849014043808 second(s).
# 1.0 hour(s), 54.0 minute(s), and 15.450668444999792 second(s).
# 1.0 hour(s), 54.0 minute(s), and 17.444303888263676 second(s).
# 1.0 hour(s), 54.0 minute(s), and 9.165008078760366 second(s).
# 1.0 hour(s), 54.0 minute(s), and 5.73765631283004 second(s).
# 1.0 hour(s), 54.0 minute(s), and 0.7964255464248708 second(s).
# 1.0 hour(s), 54.0 minute(s), and 0.4701908997130886 second(s).
# 1.0 hour(s), 54.0 minute(s), and 1.2272191719275725 second(s).
# 1.0 hour(s), 54.0 minute(s), and 5.004786597357452 second(s).
# 1.0 hour(s), 54.0 minute(s), and 8.165912912316344 second(s).
# 1.0 hour(s), 54.0 minute(s), and 19.06529402732849 second(s).
# 1.0 hour(s), 54.0 minute(s), and 18.128709872564286 second(s).
# 1.0 hour(s), 54.0 minute(s), and 20.68274318544445 second(s).
# 1.0 hour(s), 54.0 minute(s), and 25.37223333816928 second(s).
# 1.0 hour(s), 54.0 minute(s), and 22.14045642583733 second(s).
# 1.0 hour(s), 54.0 minute(s), and 13.961236425592688 second(s).
# 1.0 hour(s), 54.0 minute(s), and 6.2722392082214355 second(s).
# 1.0 hour(s), 54.0 minute(s), and 8.032103879952047 second(s).
# 1.0 hour(s), 54.0 minute(s), and 7.7924000635375705 second(s).
# 1.0 hour(s), 54.0 minute(s), and 2.365689349461718 second(s).
# 1.0 hour(s), 54.0 minute(s), and 8.10823932148196 second(s).
# 1.0 hour(s), 54.0 minute(s), and 6.966260811862412 second(s).
# 1.0 hour(s), 54.0 minute(s), and 5.818138710288622 second(s).
# 1.0 hour(s), 54.0 minute(s), and 3.8728579351272856 second(s).
# 1.0 hour(s), 53.0 minute(s), and 59.98479084535029 second(s).
# 1.0 hour(s), 53.0 minute(s), and 53.889235158983865 second(s).
# 1.0 hour(s), 53.0 minute(s), and 51.88651490211396 second(s).
# 1.0 hour(s), 53.0 minute(s), and 53.1376331848096 second(s).
# 1.0 hour(s), 53.0 minute(s), and 50.96571667298031 second(s).
# 1.0 hour(s), 53.0 minute(s), and 57.578167405179556 second(s).
# 1.0 hour(s), 53.0 minute(s), and 59.7854655600604 second(s).
# 1.0 hour(s), 54.0 minute(s), and 0.0035407417690294096 second(s).
# 1.0 hour(s), 53.0 minute(s), and 57.37481852372457 second(s).
# 1.0 hour(s), 53.0 minute(s), and 51.837479089954286 second(s).
# 1.0 hour(s), 53.0 minute(s), and 49.04006936598762 second(s).
# 1.0 hour(s), 53.0 minute(s), and 46.3706642738498 second(s).
# 1.0 hour(s), 53.0 minute(s), and 47.52766799926758 second(s).
# 1.0 hour(s), 53.0 minute(s), and 45.84290569371478 second(s).
# 1.0 hour(s), 53.0 minute(s), and 42.72176211020451 second(s).
# 1.0 hour(s), 53.0 minute(s), and 42.2518704169006 second(s).
# 1.0 hour(s), 53.0 minute(s), and 39.97317497546828 second(s).
# 1.0 hour(s), 53.0 minute(s), and 38.92502431642424 second(s).
# 1.0 hour(s), 53.0 minute(s), and 36.71519687040836 second(s).
# 1.0 hour(s), 53.0 minute(s), and 37.22414506707264 second(s).
# 1.0 hour(s), 53.0 minute(s), and 32.797456361628974 second(s).
# 1.0 hour(s), 53.0 minute(s), and 30.58384850265793 second(s).
# 1.0 hour(s), 53.0 minute(s), and 27.05039165236758 second(s).
# 1.0 hour(s), 53.0 minute(s), and 27.083286970585505 second(s).
# 1.0 hour(s), 53.0 minute(s), and 27.352309720857193 second(s).
# 1.0 hour(s), 53.0 minute(s), and 30.2752686580734 second(s).
# 1.0 hour(s), 53.0 minute(s), and 26.650284612388532 second(s).
# 1.0 hour(s), 53.0 minute(s), and 22.929647995078085 second(s).
# 1.0 hour(s), 53.0 minute(s), and 18.365335390484688 second(s).
# 1.0 hour(s), 53.0 minute(s), and 18.20134402544045 second(s).
# 1.0 hour(s), 53.0 minute(s), and 13.79187396017187 second(s).
# 1.0 hour(s), 53.0 minute(s), and 8.531155225608927 second(s).
# 1.0 hour(s), 53.0 minute(s), and 8.465232213338822 second(s).
# 1.0 hour(s), 53.0 minute(s), and 1.838102827387047 second(s).
# 1.0 hour(s), 52.0 minute(s), and 59.5017466506024 second(s).
# 1.0 hour(s), 52.0 minute(s), and 59.284410862418554 second(s).
# 1.0 hour(s), 52.0 minute(s), and 59.52027401616397 second(s).
# 1.0 hour(s), 52.0 minute(s), and 57.621177434921265 second(s).
# 1.0 hour(s), 52.0 minute(s), and 58.01466208791044 second(s).
# 1.0 hour(s), 52.0 minute(s), and 53.232979751946914 second(s).
# 1.0 hour(s), 52.0 minute(s), and 50.1439744681129 second(s).
# 1.0 hour(s), 52.0 minute(s), and 45.683591502581294 second(s).
# 1.0 hour(s), 52.0 minute(s), and 39.546676305624715 second(s).
# 1.0 hour(s), 52.0 minute(s), and 41.185639579787676 second(s).
# 1.0 hour(s), 52.0 minute(s), and 43.18315193147373 second(s).
# 1.0 hour(s), 52.0 minute(s), and 38.608319277153896 second(s).
# 1.0 hour(s), 52.0 minute(s), and 40.29797988151404 second(s).
# 1.0 hour(s), 52.0 minute(s), and 39.4159471988678 second(s).
# 1.0 hour(s), 52.0 minute(s), and 38.70537387623517 second(s).
# 1.0 hour(s), 52.0 minute(s), and 34.96412193514061 second(s).
# 1.0 hour(s), 52.0 minute(s), and 36.08937964232064 second(s).
# 1.0 hour(s), 52.0 minute(s), and 32.591916082574244 second(s).
# 1.0 hour(s), 52.0 minute(s), and 33.19077546255903 second(s).
# 1.0 hour(s), 52.0 minute(s), and 26.792744918918288 second(s).
# 1.0 hour(s), 52.0 minute(s), and 22.45367251315656 second(s).
# 1.0 hour(s), 52.0 minute(s), and 19.85678062572333 second(s).
# 1.0 hour(s), 52.0 minute(s), and 19.06620416376336 second(s).
# 1.0 hour(s), 52.0 minute(s), and 16.39028549194336 second(s).
# 1.0 hour(s), 52.0 minute(s), and 14.764654368570518 second(s).
# 1.0 hour(s), 52.0 minute(s), and 14.142275805376812 second(s).
# 1.0 hour(s), 52.0 minute(s), and 12.25346856503893 second(s).
# 1.0 hour(s), 52.0 minute(s), and 11.038732032648113 second(s).
# 1.0 hour(s), 52.0 minute(s), and 14.402330160140991 second(s).
# 1.0 hour(s), 52.0 minute(s), and 10.661388485636962 second(s).
# 1.0 hour(s), 52.0 minute(s), and 7.527210285788897 second(s).
# 1.0 hour(s), 52.0 minute(s), and 6.097161690394387 second(s).
# 1.0 hour(s), 52.0 minute(s), and 4.982453110930692 second(s).
# 1.0 hour(s), 52.0 minute(s), and 0.32843410584337107 second(s).
# 1.0 hour(s), 51.0 minute(s), and 57.08525337317042 second(s).
# 1.0 hour(s), 51.0 minute(s), and 59.163593703773586 second(s).
# 1.0 hour(s), 51.0 minute(s), and 58.112194242356054 second(s).
# 1.0 hour(s), 51.0 minute(s), and 55.74601749354224 second(s).
# 1.0 hour(s), 51.0 minute(s), and 53.36218535900116 second(s).
# 1.0 hour(s), 51.0 minute(s), and 50.906706573060546 second(s).
# 1.0 hour(s), 51.0 minute(s), and 52.225458171632454 second(s).
# 1.0 hour(s), 51.0 minute(s), and 48.34146049710216 second(s).
# 1.0 hour(s), 51.0 minute(s), and 45.256532733033964 second(s).
# 1.0 hour(s), 51.0 minute(s), and 45.77115899866294 second(s).
# 1.0 hour(s), 51.0 minute(s), and 48.15677094746843 second(s).
# 1.0 hour(s), 51.0 minute(s), and 50.524761872376985 second(s).
# 1.0 hour(s), 51.0 minute(s), and 51.89644940694143 second(s).
# 1.0 hour(s), 51.0 minute(s), and 50.48727272389169 second(s).
# 1.0 hour(s), 51.0 minute(s), and 50.50061467114574 second(s).
# 1.0 hour(s), 51.0 minute(s), and 52.079938938743 second(s).
# 1.0 hour(s), 51.0 minute(s), and 54.63489683284297 second(s).
# 1.0 hour(s), 51.0 minute(s), and 50.24419084587498 second(s).
# 1.0 hour(s), 51.0 minute(s), and 50.27567774674026 second(s).
# 1.0 hour(s), 51.0 minute(s), and 49.490062168666554 second(s).
# 1.0 hour(s), 51.0 minute(s), and 48.75209927558899 second(s).
# 1.0 hour(s), 51.0 minute(s), and 49.77950455105292 second(s).
# 1.0 hour(s), 51.0 minute(s), and 48.880670025107065 second(s).
# 1.0 hour(s), 51.0 minute(s), and 49.135050601798866 second(s).
# 1.0 hour(s), 51.0 minute(s), and 48.405534373388946 second(s).
# 1.0 hour(s), 51.0 minute(s), and 44.763548598104535 second(s).
# 1.0 hour(s), 51.0 minute(s), and 44.4325662130841 second(s).
# 1.0 hour(s), 51.0 minute(s), and 43.484117251276075 second(s).
# 1.0 hour(s), 51.0 minute(s), and 40.74911241945938 second(s).
# 1.0 hour(s), 51.0 minute(s), and 36.20568808349344 second(s).
# 1.0 hour(s), 51.0 minute(s), and 36.17905969773619 second(s).
# 1.0 hour(s), 51.0 minute(s), and 34.02483802173265 second(s).
# 1.0 hour(s), 51.0 minute(s), and 30.085617877068216 second(s).
# 1.0 hour(s), 51.0 minute(s), and 26.760290769041603 second(s).
# 1.0 hour(s), 51.0 minute(s), and 23.760382953442786 second(s).
# 1.0 hour(s), 51.0 minute(s), and 22.472518073326682 second(s).
# 1.0 hour(s), 51.0 minute(s), and 22.882261594136253 second(s).
# 1.0 hour(s), 51.0 minute(s), and 21.801525487800973 second(s).
# 1.0 hour(s), 51.0 minute(s), and 20.866143361809918 second(s).
# 1.0 hour(s), 51.0 minute(s), and 17.632187244219494 second(s).
# 1.0 hour(s), 51.0 minute(s), and 14.712226132956857 second(s).
# 1.0 hour(s), 51.0 minute(s), and 15.225200726900766 second(s).
# 1.0 hour(s), 51.0 minute(s), and 14.674139213079798 second(s).
# 1.0 hour(s), 51.0 minute(s), and 10.685028386475096 second(s).
# 1.0 hour(s), 51.0 minute(s), and 10.459894180298761 second(s).
# 1.0 hour(s), 51.0 minute(s), and 9.062457472530696 second(s).
# 1.0 hour(s), 51.0 minute(s), and 8.948847714036674 second(s).
# 1.0 hour(s), 51.0 minute(s), and 8.633179171332813 second(s).
# 1.0 hour(s), 51.0 minute(s), and 6.070774630004053 second(s).
# 1.0 hour(s), 51.0 minute(s), and 5.627481890887793 second(s).
# 1.0 hour(s), 51.0 minute(s), and 3.2411407081826837 second(s).
# 1.0 hour(s), 51.0 minute(s), and 0.6564291272188711 second(s).
# 1.0 hour(s), 50.0 minute(s), and 59.513175184910324 second(s).
# 1.0 hour(s), 50.0 minute(s), and 58.27579017004882 second(s).
# 1.0 hour(s), 50.0 minute(s), and 56.90006019955581 second(s).
# 1.0 hour(s), 50.0 minute(s), and 55.81939478282129 second(s).
# 1.0 hour(s), 50.0 minute(s), and 53.1305929129976 second(s).
# 1.0 hour(s), 50.0 minute(s), and 51.51185786891983 second(s).
# 1.0 hour(s), 50.0 minute(s), and 47.99256503916149 second(s).
# 1.0 hour(s), 50.0 minute(s), and 49.149772899096206 second(s).
# 1.0 hour(s), 50.0 minute(s), and 49.10736366554465 second(s).
# 1.0 hour(s), 50.0 minute(s), and 49.03005322443187 second(s).
# 1.0 hour(s), 50.0 minute(s), and 48.54493656727118 second(s).
# 1.0 hour(s), 50.0 minute(s), and 45.42876881986922 second(s).
# 1.0 hour(s), 50.0 minute(s), and 46.489413022994995 second(s).
# 1.0 hour(s), 50.0 minute(s), and 44.14383413780888 second(s).
# 1.0 hour(s), 50.0 minute(s), and 43.14295820717416 second(s).
# 1.0 hour(s), 50.0 minute(s), and 42.97470028945736 second(s).
# 1.0 hour(s), 50.0 minute(s), and 44.82255039044776 second(s).
# 1.0 hour(s), 50.0 minute(s), and 43.02902878655368 second(s).
# 1.0 hour(s), 50.0 minute(s), and 44.15696602796106 second(s).
# 1.0 hour(s), 50.0 minute(s), and 43.31494347114403 second(s).
# 1.0 hour(s), 50.0 minute(s), and 42.75065616139182 second(s).
# 1.0 hour(s), 50.0 minute(s), and 40.406101747371395 second(s).
# 1.0 hour(s), 50.0 minute(s), and 41.22564019327547 second(s).
# 1.0 hour(s), 50.0 minute(s), and 40.04125877789102 second(s).
# 1.0 hour(s), 50.0 minute(s), and 39.80149479569991 second(s).
# 1.0 hour(s), 50.0 minute(s), and 37.912907356868345 second(s).
# 1.0 hour(s), 50.0 minute(s), and 36.98689330744946 second(s).
# 1.0 hour(s), 50.0 minute(s), and 34.18963836608964 second(s).
# 1.0 hour(s), 50.0 minute(s), and 32.293860694108844 second(s).
# 1.0 hour(s), 50.0 minute(s), and 32.87861238049027 second(s).
# 1.0 hour(s), 50.0 minute(s), and 33.12394819139354 second(s).
# 1.0 hour(s), 50.0 minute(s), and 32.69670395671619 second(s).
# 1.0 hour(s), 50.0 minute(s), and 32.32044259707163 second(s).
# 1.0 hour(s), 50.0 minute(s), and 32.98291847023302 second(s).
# 1.0 hour(s), 50.0 minute(s), and 30.360742180801026 second(s).
# 1.0 hour(s), 50.0 minute(s), and 30.013038145661085 second(s).
# 1.0 hour(s), 50.0 minute(s), and 27.480152622597416 second(s).
# 1.0 hour(s), 50.0 minute(s), and 26.608343620689993 second(s).
# 1.0 hour(s), 50.0 minute(s), and 24.958403831575197 second(s).
# 1.0 hour(s), 50.0 minute(s), and 23.965445937415097 second(s).
# 1.0 hour(s), 50.0 minute(s), and 21.33888069275872 second(s).
# 1.0 hour(s), 50.0 minute(s), and 20.36515712259279 second(s).
# 1.0 hour(s), 50.0 minute(s), and 18.6082501411438 second(s).
# 1.0 hour(s), 50.0 minute(s), and 17.251996147680075 second(s).
# 1.0 hour(s), 50.0 minute(s), and 14.990177582180877 second(s).
# 1.0 hour(s), 50.0 minute(s), and 13.843889358957313 second(s).
# 1.0 hour(s), 50.0 minute(s), and 13.125509605632942 second(s).
# 1.0 hour(s), 50.0 minute(s), and 13.835823900559262 second(s).
# 1.0 hour(s), 50.0 minute(s), and 11.635149754583836 second(s).
# 1.0 hour(s), 50.0 minute(s), and 14.077883609074888 second(s).
# 1.0 hour(s), 50.0 minute(s), and 14.336741096290098 second(s).
# 1.0 hour(s), 50.0 minute(s), and 12.419926893757292 second(s).
# 1.0 hour(s), 50.0 minute(s), and 10.270229651378031 second(s).
# 1.0 hour(s), 50.0 minute(s), and 8.071994445333075 second(s).
# 1.0 hour(s), 50.0 minute(s), and 6.676709688347728 second(s).
# 1.0 hour(s), 50.0 minute(s), and 4.235845572141443 second(s).
# 1.0 hour(s), 50.0 minute(s), and 2.431969613739966 second(s).
# 1.0 hour(s), 49.0 minute(s), and 59.611673638505636 second(s).
# 1.0 hour(s), 49.0 minute(s), and 58.014077597094 second(s).
# 1.0 hour(s), 49.0 minute(s), and 58.299013583401575 second(s).
# 1.0 hour(s), 49.0 minute(s), and 57.74004684277406 second(s).
# 1.0 hour(s), 49.0 minute(s), and 55.62533350504873 second(s).
# 1.0 hour(s), 49.0 minute(s), and 56.00633662718337 second(s).
# 1.0 hour(s), 49.0 minute(s), and 56.199010450461174 second(s).
# 1.0 hour(s), 49.0 minute(s), and 51.681244716924084 second(s).
# 1.0 hour(s), 49.0 minute(s), and 49.0941733964637 second(s).
# 1.0 hour(s), 49.0 minute(s), and 49.03710202579077 second(s).
# 1.0 hour(s), 49.0 minute(s), and 48.0238256237717 second(s).
# 1.0 hour(s), 49.0 minute(s), and 48.36099951509095 second(s).
# 1.0 hour(s), 49.0 minute(s), and 46.1590994144608 second(s).
# 1.0 hour(s), 49.0 minute(s), and 45.62954186707066 second(s).
# 1.0 hour(s), 49.0 minute(s), and 43.72146123882703 second(s).
# 1.0 hour(s), 49.0 minute(s), and 42.525992938450145 second(s).
# 1.0 hour(s), 49.0 minute(s), and 42.505611040413896 second(s).
# 1.0 hour(s), 49.0 minute(s), and 41.56166872403264 second(s).
# 1.0 hour(s), 49.0 minute(s), and 40.12285805927968 second(s).
# 1.0 hour(s), 49.0 minute(s), and 39.59841790669361 second(s).
# 1.0 hour(s), 49.0 minute(s), and 39.37496000005467 second(s).
# 1.0 hour(s), 49.0 minute(s), and 37.153724885486554 second(s).
# 1.0 hour(s), 49.0 minute(s), and 37.144476917147585 second(s).
# 1.0 hour(s), 49.0 minute(s), and 36.106411662366554 second(s).
# 1.0 hour(s), 49.0 minute(s), and 33.40160474480308 second(s).
# 1.0 hour(s), 49.0 minute(s), and 32.5594791215035 second(s).
# 1.0 hour(s), 49.0 minute(s), and 32.07703390563802 second(s).
# 1.0 hour(s), 49.0 minute(s), and 30.547645431675846 second(s).
# 1.0 hour(s), 49.0 minute(s), and 30.868576116528857 second(s).
# 1.0 hour(s), 49.0 minute(s), and 29.44659283047622 second(s).
# 1.0 hour(s), 49.0 minute(s), and 27.27453374862671 second(s).
# 1.0 hour(s), 49.0 minute(s), and 26.603341669649126 second(s).
# 1.0 hour(s), 49.0 minute(s), and 25.245415714051887 second(s).
# 1.0 hour(s), 49.0 minute(s), and 22.27615376606809 second(s).
# 1.0 hour(s), 49.0 minute(s), and 18.32204977804122 second(s).
# 1.0 hour(s), 49.0 minute(s), and 17.5741347471876 second(s).
# 1.0 hour(s), 49.0 minute(s), and 16.008982300361822 second(s).
# 1.0 hour(s), 49.0 minute(s), and 14.95895593055775 second(s).
# 1.0 hour(s), 49.0 minute(s), and 13.704909233370017 second(s).
# 1.0 hour(s), 49.0 minute(s), and 12.12508244890887 second(s).
# 1.0 hour(s), 49.0 minute(s), and 11.199341648914015 second(s).
# 1.0 hour(s), 49.0 minute(s), and 8.345278473461804 second(s).
# 1.0 hour(s), 49.0 minute(s), and 7.16931276601008 second(s).
# 1.0 hour(s), 49.0 minute(s), and 6.6626896053167 second(s).
# 1.0 hour(s), 49.0 minute(s), and 3.7034074797220455 second(s).
# 1.0 hour(s), 49.0 minute(s), and 3.162642440487616 second(s).
# 1.0 hour(s), 49.0 minute(s), and 2.661364436533404 second(s).
# 1.0 hour(s), 49.0 minute(s), and 2.544966000778004 second(s).
# 1.0 hour(s), 49.0 minute(s), and 1.4006602619401747 second(s).
# 1.0 hour(s), 48.0 minute(s), and 59.224113195565224 second(s).
# 1.0 hour(s), 48.0 minute(s), and 58.243668192908444 second(s).
# 1.0 hour(s), 48.0 minute(s), and 56.77079088476603 second(s).
# 1.0 hour(s), 48.0 minute(s), and 56.21526497470859 second(s).
# 1.0 hour(s), 48.0 minute(s), and 53.63504670251132 second(s).
# 1.0 hour(s), 48.0 minute(s), and 51.26830235768284 second(s).
# 1.0 hour(s), 48.0 minute(s), and 50.21093612909317 second(s).
# 1.0 hour(s), 48.0 minute(s), and 48.55319250484081 second(s).
# 1.0 hour(s), 48.0 minute(s), and 46.962585786855925 second(s).
# 1.0 hour(s), 48.0 minute(s), and 45.597886859078244 second(s).
# 1.0 hour(s), 48.0 minute(s), and 43.005166639516574 second(s).
# 1.0 hour(s), 48.0 minute(s), and 42.34978939936718 second(s).
# 1.0 hour(s), 48.0 minute(s), and 42.651036944125735 second(s).
# 1.0 hour(s), 48.0 minute(s), and 41.73959774562718 second(s).
# 1.0 hour(s), 48.0 minute(s), and 40.96772105519358 second(s).
# 1.0 hour(s), 48.0 minute(s), and 40.10637360140936 second(s).
# 1.0 hour(s), 48.0 minute(s), and 38.40300941467285 second(s).
# 1.0 hour(s), 48.0 minute(s), and 38.497527609419194 second(s).
# 1.0 hour(s), 48.0 minute(s), and 36.41513573118027 second(s).
# 1.0 hour(s), 48.0 minute(s), and 36.3852542670993 second(s).
# 1.0 hour(s), 48.0 minute(s), and 37.003910221739716 second(s).
# 1.0 hour(s), 48.0 minute(s), and 33.88798938936179 second(s).
# 1.0 hour(s), 48.0 minute(s), and 32.603139996528625 second(s).
# 1.0 hour(s), 48.0 minute(s), and 30.818971563870946 second(s).
# 1.0 hour(s), 48.0 minute(s), and 29.865721502247652 second(s).
# 1.0 hour(s), 48.0 minute(s), and 28.359140991813547 second(s).
# 1.0 hour(s), 48.0 minute(s), and 27.237489532021755 second(s).
# 1.0 hour(s), 48.0 minute(s), and 27.38590129869044 second(s).
# 1.0 hour(s), 48.0 minute(s), and 26.774776507539173 second(s).
# 1.0 hour(s), 48.0 minute(s), and 24.351299839881904 second(s).
# 1.0 hour(s), 48.0 minute(s), and 23.09642687509222 second(s).
# 1.0 hour(s), 48.0 minute(s), and 21.80307812276169 second(s).
# 1.0 hour(s), 48.0 minute(s), and 20.091624633425454 second(s).
# 1.0 hour(s), 48.0 minute(s), and 18.264709832688823 second(s).
# 1.0 hour(s), 48.0 minute(s), and 17.213141301582255 second(s).
# 1.0 hour(s), 48.0 minute(s), and 17.17344189168398 second(s).
# 1.0 hour(s), 48.0 minute(s), and 16.021536929266404 second(s).
# 1.0 hour(s), 48.0 minute(s), and 14.218452007342421 second(s).
# 1.0 hour(s), 48.0 minute(s), and 13.554509471762685 second(s).
# 1.0 hour(s), 48.0 minute(s), and 11.397190875440174 second(s).
# 1.0 hour(s), 48.0 minute(s), and 10.34768688746044 second(s).
# 1.0 hour(s), 48.0 minute(s), and 8.745902672620105 second(s).
# 1.0 hour(s), 48.0 minute(s), and 7.628516781196595 second(s).
# 1.0 hour(s), 48.0 minute(s), and 6.704691394705151 second(s).
# 1.0 hour(s), 48.0 minute(s), and 5.02518641482493 second(s).
# 1.0 hour(s), 48.0 minute(s), and 3.632054974442326 second(s).
# 1.0 hour(s), 48.0 minute(s), and 2.6389153798427287 second(s).
# 1.0 hour(s), 47.0 minute(s), and 58.74917602208825 second(s).
# 1.0 hour(s), 47.0 minute(s), and 56.37482129012642 second(s).
# 1.0 hour(s), 47.0 minute(s), and 55.8730739837838 second(s).
# 1.0 hour(s), 47.0 minute(s), and 54.779657138573384 second(s).
# 1.0 hour(s), 47.0 minute(s), and 52.5150605619765 second(s).
# 1.0 hour(s), 47.0 minute(s), and 51.25668477230374 second(s).
# 1.0 hour(s), 47.0 minute(s), and 50.591488416577704 second(s).
# 1.0 hour(s), 47.0 minute(s), and 48.95822822010996 second(s).
# 1.0 hour(s), 47.0 minute(s), and 47.3953223364133 second(s).
# 1.0 hour(s), 47.0 minute(s), and 45.52030944179842 second(s).
# 1.0 hour(s), 47.0 minute(s), and 42.97381176781437 second(s).
# 1.0 hour(s), 47.0 minute(s), and 40.944357325953206 second(s).
# 1.0 hour(s), 47.0 minute(s), and 39.78456592495877 second(s).
# 1.0 hour(s), 47.0 minute(s), and 38.81232778401318 second(s).
# 1.0 hour(s), 47.0 minute(s), and 37.75133681297302 second(s).
# 1.0 hour(s), 47.0 minute(s), and 36.2997849849944 second(s).
# 1.0 hour(s), 47.0 minute(s), and 33.47053747720929 second(s).
# 1.0 hour(s), 47.0 minute(s), and 33.278870957237814 second(s).
# 1.0 hour(s), 47.0 minute(s), and 32.0062773315758 second(s).
# 1.0 hour(s), 47.0 minute(s), and 30.258421408502727 second(s).
# 1.0 hour(s), 47.0 minute(s), and 29.569470562020797 second(s).
# 1.0 hour(s), 47.0 minute(s), and 27.774263918711767 second(s).
# 1.0 hour(s), 47.0 minute(s), and 25.257281932133992 second(s).
# 1.0 hour(s), 47.0 minute(s), and 23.745287120342255 second(s).
# 1.0 hour(s), 47.0 minute(s), and 23.7338392796446 second(s).
# 1.0 hour(s), 47.0 minute(s), and 22.1830547695954 second(s).
# 1.0 hour(s), 47.0 minute(s), and 20.764327426289128 second(s).
# 1.0 hour(s), 47.0 minute(s), and 18.608036468937826 second(s).
# 1.0 hour(s), 47.0 minute(s), and 15.091569613674437 second(s).
# 1.0 hour(s), 47.0 minute(s), and 13.90589138177711 second(s).
# 1.0 hour(s), 47.0 minute(s), and 12.966828571256883 second(s).
# 1.0 hour(s), 47.0 minute(s), and 10.755740418725509 second(s).
# 1.0 hour(s), 47.0 minute(s), and 8.970306403158247 second(s).
# 1.0 hour(s), 47.0 minute(s), and 6.789170044932689 second(s).
# 1.0 hour(s), 47.0 minute(s), and 5.032515302489628 second(s).
# 1.0 hour(s), 47.0 minute(s), and 4.26696463546341 second(s).
# 1.0 hour(s), 47.0 minute(s), and 2.6159527884319687 second(s).
# 1.0 hour(s), 47.0 minute(s), and 2.0657827183231348 second(s).
# 1.0 hour(s), 47.0 minute(s), and 0.9454934830055208 second(s).
# 1.0 hour(s), 46.0 minute(s), and 59.67416489124207 second(s).
# 1.0 hour(s), 46.0 minute(s), and 57.71327093117179 second(s).
# 1.0 hour(s), 46.0 minute(s), and 55.97298006038727 second(s).
# 1.0 hour(s), 46.0 minute(s), and 54.16614604587903 second(s).
# 1.0 hour(s), 46.0 minute(s), and 54.12045276283061 second(s).
# 1.0 hour(s), 46.0 minute(s), and 50.939076797461894 second(s).
# 1.0 hour(s), 46.0 minute(s), and 48.36752718657681 second(s).
# 1.0 hour(s), 46.0 minute(s), and 46.67204795598445 second(s).
# 1.0 hour(s), 46.0 minute(s), and 45.46267512265331 second(s).
# 1.0 hour(s), 46.0 minute(s), and 43.63427313324246 second(s).
# 1.0 hour(s), 46.0 minute(s), and 42.24521395055217 second(s).
# 1.0 hour(s), 46.0 minute(s), and 39.62673859584629 second(s).
# 1.0 hour(s), 46.0 minute(s), and 38.38570321184943 second(s).
# 1.0 hour(s), 46.0 minute(s), and 36.854867600933176 second(s).
# 1.0 hour(s), 46.0 minute(s), and 34.93669719511672 second(s).
# 1.0 hour(s), 46.0 minute(s), and 33.99444155520723 second(s).
# 1.0 hour(s), 46.0 minute(s), and 33.42481752083859 second(s).
# 1.0 hour(s), 46.0 minute(s), and 30.824463388617005 second(s).
# 1.0 hour(s), 46.0 minute(s), and 30.60258114508997 second(s).
# 1.0 hour(s), 46.0 minute(s), and 28.9410833464608 second(s).
# 1.0 hour(s), 46.0 minute(s), and 27.542940423602886 second(s).
# 1.0 hour(s), 46.0 minute(s), and 27.93021642793701 second(s).
# 1.0 hour(s), 46.0 minute(s), and 26.636024738375454 second(s).
# 1.0 hour(s), 46.0 minute(s), and 24.87560219685838 second(s).
# 1.0 hour(s), 46.0 minute(s), and 23.18186891303867 second(s).
# 1.0 hour(s), 46.0 minute(s), and 21.9637746670669 second(s).
# 1.0 hour(s), 46.0 minute(s), and 21.48633629727192 second(s).
# 1.0 hour(s), 46.0 minute(s), and 19.750031696270526 second(s).
# 1.0 hour(s), 46.0 minute(s), and 17.726665447805317 second(s).
# 1.0 hour(s), 46.0 minute(s), and 15.738612476762682 second(s).
# 1.0 hour(s), 46.0 minute(s), and 14.90237453926511 second(s).
# 1.0 hour(s), 46.0 minute(s), and 12.259420886117368 second(s).
# 1.0 hour(s), 46.0 minute(s), and 9.135918754118393 second(s).
# 1.0 hour(s), 46.0 minute(s), and 7.895239602060428 second(s).
# 1.0 hour(s), 46.0 minute(s), and 6.0586568606067885 second(s).
# 1.0 hour(s), 46.0 minute(s), and 3.573091230173304 second(s).
# 1.0 hour(s), 46.0 minute(s), and 0.9567937938445539 second(s).
# 1.0 hour(s), 46.0 minute(s), and 0.10260890223071328 second(s).
# 1.0 hour(s), 46.0 minute(s), and 0.2569851940625085 second(s).
# 1.0 hour(s), 45.0 minute(s), and 59.8939594956355 second(s).
# 1.0 hour(s), 45.0 minute(s), and 58.572672063653954 second(s).
# 1.0 hour(s), 45.0 minute(s), and 57.67402708070858 second(s).
# 1.0 hour(s), 45.0 minute(s), and 55.46201776487305 second(s).
# 1.0 hour(s), 45.0 minute(s), and 54.211590814267765 second(s).
# 1.0 hour(s), 45.0 minute(s), and 53.925990708239624 second(s).
# 1.0 hour(s), 45.0 minute(s), and 52.200461658199856 second(s).
# 1.0 hour(s), 45.0 minute(s), and 50.31310126599692 second(s).
# 1.0 hour(s), 45.0 minute(s), and 49.508851352154124 second(s).
# 1.0 hour(s), 45.0 minute(s), and 47.532118627003 second(s).
# 1.0 hour(s), 45.0 minute(s), and 45.49742349696771 second(s).
# 1.0 hour(s), 45.0 minute(s), and 44.36657990349704 second(s).
# 1.0 hour(s), 45.0 minute(s), and 42.52765677403477 second(s).
# 1.0 hour(s), 45.0 minute(s), and 40.600251212584226 second(s).
# 1.0 hour(s), 45.0 minute(s), and 39.40895260459183 second(s).
# 1.0 hour(s), 45.0 minute(s), and 38.387024528655274 second(s).
# 1.0 hour(s), 45.0 minute(s), and 35.903501641620096 second(s).
# 1.0 hour(s), 45.0 minute(s), and 34.85155808298259 second(s).
# 1.0 hour(s), 45.0 minute(s), and 33.53927075993306 second(s).
# 1.0 hour(s), 45.0 minute(s), and 31.39275461096986 second(s).
# 1.0 hour(s), 45.0 minute(s), and 29.735121483377043 second(s).
# 1.0 hour(s), 45.0 minute(s), and 26.52152892817685 second(s).
# 1.0 hour(s), 45.0 minute(s), and 25.441747341653354 second(s).
# 1.0 hour(s), 45.0 minute(s), and 23.42645034852012 second(s).
# 1.0 hour(s), 45.0 minute(s), and 22.797087537547668 second(s).
# 1.0 hour(s), 45.0 minute(s), and 20.745213253744623 second(s).
# 1.0 hour(s), 45.0 minute(s), and 19.370090623056058 second(s).
# 1.0 hour(s), 45.0 minute(s), and 18.014336707766233 second(s).
# 1.0 hour(s), 45.0 minute(s), and 16.609750041104235 second(s).
# 1.0 hour(s), 45.0 minute(s), and 14.342534635820812 second(s).
# 1.0 hour(s), 45.0 minute(s), and 13.075459268301529 second(s).
# 1.0 hour(s), 45.0 minute(s), and 11.86579610946319 second(s).
# 1.0 hour(s), 45.0 minute(s), and 10.481906239900127 second(s).
# 1.0 hour(s), 45.0 minute(s), and 9.414852522187175 second(s).
# 1.0 hour(s), 45.0 minute(s), and 7.129613656574293 second(s).
# 1.0 hour(s), 45.0 minute(s), and 6.549843312315716 second(s).
# 1.0 hour(s), 45.0 minute(s), and 7.320329352429326 second(s).
# 1.0 hour(s), 45.0 minute(s), and 6.197081674046785 second(s).
# 1.0 hour(s), 45.0 minute(s), and 4.1994460348814755 second(s).
# 1.0 hour(s), 45.0 minute(s), and 2.2234789686717704 second(s).
# 1.0 hour(s), 45.0 minute(s), and 0.5809138901295228 second(s).
# 1.0 hour(s), 44.0 minute(s), and 58.82633550961782 second(s).
# 1.0 hour(s), 44.0 minute(s), and 57.778769324078894 second(s).
# 1.0 hour(s), 44.0 minute(s), and 57.12368205177245 second(s).
# 1.0 hour(s), 44.0 minute(s), and 55.42621173917905 second(s).
# 1.0 hour(s), 44.0 minute(s), and 54.04760745931344 second(s).
# 1.0 hour(s), 44.0 minute(s), and 52.603649655568006 second(s).
# 1.0 hour(s), 44.0 minute(s), and 51.51320709613174 second(s).
# 1.0 hour(s), 44.0 minute(s), and 50.99653659415162 second(s).
# 1.0 hour(s), 44.0 minute(s), and 48.27324345072702 second(s).
# 1.0 hour(s), 44.0 minute(s), and 47.43972106409001 second(s).
# 1.0 hour(s), 44.0 minute(s), and 45.87581132869309 second(s).
# 1.0 hour(s), 44.0 minute(s), and 43.93578550043458 second(s).
# 1.0 hour(s), 44.0 minute(s), and 42.86027867425764 second(s).
# 1.0 hour(s), 44.0 minute(s), and 41.508819450954434 second(s).
# 1.0 hour(s), 44.0 minute(s), and 40.28509211540222 second(s).
# 1.0 hour(s), 44.0 minute(s), and 39.17908294273093 second(s).
# 1.0 hour(s), 44.0 minute(s), and 37.85353072997077 second(s).
# 1.0 hour(s), 44.0 minute(s), and 36.15580652897006 second(s).
# 1.0 hour(s), 44.0 minute(s), and 35.418640187466735 second(s).
# 1.0 hour(s), 44.0 minute(s), and 34.7778847289228 second(s).
# 1.0 hour(s), 44.0 minute(s), and 33.178879737854004 second(s).
# 1.0 hour(s), 44.0 minute(s), and 31.96722498672898 second(s).
# 1.0 hour(s), 44.0 minute(s), and 31.94771908383882 second(s).
# 1.0 hour(s), 44.0 minute(s), and 30.04763784797251 second(s).
# 1.0 hour(s), 44.0 minute(s), and 28.31461616546403 second(s).
# 1.0 hour(s), 44.0 minute(s), and 25.968334488349683 second(s).
# 1.0 hour(s), 44.0 minute(s), and 24.937568189599006 second(s).
# 1.0 hour(s), 44.0 minute(s), and 23.412886351522502 second(s).
# 1.0 hour(s), 44.0 minute(s), and 22.835831799845437 second(s).
# 1.0 hour(s), 44.0 minute(s), and 22.02553815738611 second(s).
# 1.0 hour(s), 44.0 minute(s), and 20.428447199803486 second(s).
# 1.0 hour(s), 44.0 minute(s), and 20.239090636285255 second(s).
# 1.0 hour(s), 44.0 minute(s), and 18.333506528288126 second(s).
# 1.0 hour(s), 44.0 minute(s), and 16.77163665243461 second(s).
# 1.0 hour(s), 44.0 minute(s), and 15.935584326199205 second(s).
# 1.0 hour(s), 44.0 minute(s), and 13.737192899277943 second(s).
# 1.0 hour(s), 44.0 minute(s), and 12.403440998506994 second(s).
# 1.0 hour(s), 44.0 minute(s), and 11.312504900262866 second(s).
# 1.0 hour(s), 44.0 minute(s), and 10.809138834706573 second(s).
# 1.0 hour(s), 44.0 minute(s), and 9.861203983798987 second(s).
# 1.0 hour(s), 44.0 minute(s), and 8.721675285926722 second(s).
# 1.0 hour(s), 44.0 minute(s), and 7.2884405501281435 second(s).
# 1.0 hour(s), 44.0 minute(s), and 6.413509860349222 second(s).
# 1.0 hour(s), 44.0 minute(s), and 5.424949800534705 second(s).
# 1.0 hour(s), 44.0 minute(s), and 2.8870493146305307 second(s).
# 1.0 hour(s), 44.0 minute(s), and 1.4290380932034168 second(s).
# 1.0 hour(s), 44.0 minute(s), and 0.2863549669427812 second(s).
# 1.0 hour(s), 43.0 minute(s), and 58.24205469994649 second(s).
# 1.0 hour(s), 43.0 minute(s), and 56.43783072991846 second(s).
# 1.0 hour(s), 43.0 minute(s), and 55.137855044384196 second(s).
# 1.0 hour(s), 43.0 minute(s), and 53.87636735754131 second(s).
# 1.0 hour(s), 43.0 minute(s), and 51.88983615463985 second(s).
# 1.0 hour(s), 43.0 minute(s), and 50.24210461637995 second(s).
# 1.0 hour(s), 43.0 minute(s), and 48.981220041833694 second(s).
# 1.0 hour(s), 43.0 minute(s), and 47.37660431683253 second(s).
# 1.0 hour(s), 43.0 minute(s), and 45.77706270797171 second(s).
# 1.0 hour(s), 43.0 minute(s), and 44.2825685401458 second(s).
# 1.0 hour(s), 43.0 minute(s), and 43.80334583252352 second(s).
# 1.0 hour(s), 43.0 minute(s), and 42.47359723761201 second(s).
# 1.0 hour(s), 43.0 minute(s), and 40.92814109144001 second(s).
# 1.0 hour(s), 43.0 minute(s), and 39.94556983311941 second(s).
# 1.0 hour(s), 43.0 minute(s), and 38.614733661609534 second(s).
# 1.0 hour(s), 43.0 minute(s), and 36.707338436943246 second(s).
# 1.0 hour(s), 43.0 minute(s), and 34.96637997003745 second(s).
# 1.0 hour(s), 43.0 minute(s), and 33.63679161141863 second(s).
# 1.0 hour(s), 43.0 minute(s), and 31.611456805412672 second(s).
# 1.0 hour(s), 43.0 minute(s), and 30.498182842582537 second(s).
# 1.0 hour(s), 43.0 minute(s), and 29.80436618672502 second(s).
# 1.0 hour(s), 43.0 minute(s), and 28.953171479441153 second(s).
# 1.0 hour(s), 43.0 minute(s), and 26.752629564542985 second(s).
# 1.0 hour(s), 43.0 minute(s), and 24.927883646704686 second(s).
# 1.0 hour(s), 43.0 minute(s), and 22.894747907151213 second(s).
# 1.0 hour(s), 43.0 minute(s), and 20.856259539507846 second(s).
# 1.0 hour(s), 43.0 minute(s), and 19.31556813798852 second(s).
# 1.0 hour(s), 43.0 minute(s), and 17.731116020292575 second(s).
# 1.0 hour(s), 43.0 minute(s), and 16.443972731495705 second(s).
# 1.0 hour(s), 43.0 minute(s), and 14.420355697329796 second(s).
# 1.0 hour(s), 43.0 minute(s), and 12.582965968113058 second(s).
# 1.0 hour(s), 43.0 minute(s), and 10.61992549212664 second(s).
# 1.0 hour(s), 43.0 minute(s), and 8.977267751967702 second(s).
# 1.0 hour(s), 43.0 minute(s), and 7.04194644519248 second(s).
# 1.0 hour(s), 43.0 minute(s), and 5.496908955396066 second(s).
# 1.0 hour(s), 43.0 minute(s), and 4.537388921208731 second(s).
# 1.0 hour(s), 43.0 minute(s), and 3.1422936713079253 second(s).
# 1.0 hour(s), 43.0 minute(s), and 2.117114535460132 second(s).
# 1.0 hour(s), 42.0 minute(s), and 59.95909591902637 second(s).
# 1.0 hour(s), 42.0 minute(s), and 59.07051474887976 second(s).
# 1.0 hour(s), 42.0 minute(s), and 58.04296521030392 second(s).
# 1.0 hour(s), 42.0 minute(s), and 56.967092722234156 second(s).
# 1.0 hour(s), 42.0 minute(s), and 55.375473673188026 second(s).
# 1.0 hour(s), 42.0 minute(s), and 53.96672607304754 second(s).
# 1.0 hour(s), 42.0 minute(s), and 53.23038976705993 second(s).
# 1.0 hour(s), 42.0 minute(s), and 51.55382662386364 second(s).
# 1.0 hour(s), 42.0 minute(s), and 50.00984301575318 second(s).
# 1.0 hour(s), 42.0 minute(s), and 49.17656135974539 second(s).
# 1.0 hour(s), 42.0 minute(s), and 46.969950789990435 second(s).
# 1.0 hour(s), 42.0 minute(s), and 46.08884573645082 second(s).
# 1.0 hour(s), 42.0 minute(s), and 44.51517943492945 second(s).
# 1.0 hour(s), 42.0 minute(s), and 43.041843241886454 second(s).
# 1.0 hour(s), 42.0 minute(s), and 41.125458533694655 second(s).
# 1.0 hour(s), 42.0 minute(s), and 40.41632207508792 second(s).
# 1.0 hour(s), 42.0 minute(s), and 38.79860817750068 second(s).
# 1.0 hour(s), 42.0 minute(s), and 37.59961441865835 second(s).
# 1.0 hour(s), 42.0 minute(s), and 36.164778872583156 second(s).
# 1.0 hour(s), 42.0 minute(s), and 34.92979556567116 second(s).
# 1.0 hour(s), 42.0 minute(s), and 33.37403449034082 second(s).
# 1.0 hour(s), 42.0 minute(s), and 32.82923780610599 second(s).
# 1.0 hour(s), 42.0 minute(s), and 31.78443747809615 second(s).
# 1.0 hour(s), 42.0 minute(s), and 30.242673711712087 second(s).
# 1.0 hour(s), 42.0 minute(s), and 28.836368295251305 second(s).
# 1.0 hour(s), 42.0 minute(s), and 27.151785317114445 second(s).
# 1.0 hour(s), 42.0 minute(s), and 25.402606563923655 second(s).
# 1.0 hour(s), 42.0 minute(s), and 23.416296259776573 second(s).
# 1.0 hour(s), 42.0 minute(s), and 22.83818141364827 second(s).
# 1.0 hour(s), 42.0 minute(s), and 21.766889767213797 second(s).
# 1.0 hour(s), 42.0 minute(s), and 20.427592315593756 second(s).
# 1.0 hour(s), 42.0 minute(s), and 18.555589247069292 second(s).
# 1.0 hour(s), 42.0 minute(s), and 17.859183916494658 second(s).
# 1.0 hour(s), 42.0 minute(s), and 15.539118395202422 second(s).
# 1.0 hour(s), 42.0 minute(s), and 14.333064161676702 second(s).
# 1.0 hour(s), 42.0 minute(s), and 13.977816581726984 second(s).
# 1.0 hour(s), 42.0 minute(s), and 12.464692531131732 second(s).
# 1.0 hour(s), 42.0 minute(s), and 11.924629872027253 second(s).
# 1.0 hour(s), 42.0 minute(s), and 10.129549558680083 second(s).
# 1.0 hour(s), 42.0 minute(s), and 8.59820528219916 second(s).
# 1.0 hour(s), 42.0 minute(s), and 7.663632708147816 second(s).
# 1.0 hour(s), 42.0 minute(s), and 5.812892788707359 second(s).
# 1.0 hour(s), 42.0 minute(s), and 4.681002513188105 second(s).
# 1.0 hour(s), 42.0 minute(s), and 3.53369958777148 second(s).
# 1.0 hour(s), 42.0 minute(s), and 2.4359945189962673 second(s).
# 1.0 hour(s), 42.0 minute(s), and 0.7753091014801612 second(s).
# 1.0 hour(s), 41.0 minute(s), and 59.42478309013222 second(s).
# 1.0 hour(s), 41.0 minute(s), and 58.24640127412658 second(s).
# 1.0 hour(s), 41.0 minute(s), and 56.92388353534534 second(s).
# 1.0 hour(s), 41.0 minute(s), and 55.572468429900255 second(s).
# 1.0 hour(s), 41.0 minute(s), and 54.6919282703866 second(s).
# 1.0 hour(s), 41.0 minute(s), and 52.64832694809229 second(s).
# 1.0 hour(s), 41.0 minute(s), and 51.41776229110292 second(s).
# 1.0 hour(s), 41.0 minute(s), and 49.860120514064874 second(s).
# 1.0 hour(s), 41.0 minute(s), and 48.28187160114521 second(s).
# 1.0 hour(s), 41.0 minute(s), and 46.11022117830089 second(s).
# 1.0 hour(s), 41.0 minute(s), and 45.113189083366706 second(s).
# 1.0 hour(s), 41.0 minute(s), and 43.163535431650416 second(s).
# 1.0 hour(s), 41.0 minute(s), and 42.144202664423574 second(s).
# 1.0 hour(s), 41.0 minute(s), and 39.90916073322296 second(s).
# 1.0 hour(s), 41.0 minute(s), and 39.73006749153046 second(s).
# 1.0 hour(s), 41.0 minute(s), and 38.175734836833726 second(s).
# 1.0 hour(s), 41.0 minute(s), and 36.39167849032674 second(s).
# 1.0 hour(s), 41.0 minute(s), and 34.49056892182489 second(s).
# 1.0 hour(s), 41.0 minute(s), and 33.21726220628261 second(s).
# 1.0 hour(s), 41.0 minute(s), and 32.71420435299933 second(s).
# 1.0 hour(s), 41.0 minute(s), and 32.03472739089739 second(s).
# 1.0 hour(s), 41.0 minute(s), and 30.6731453183329 second(s).
# 1.0 hour(s), 41.0 minute(s), and 29.471949903132554 second(s).
# 1.0 hour(s), 41.0 minute(s), and 27.78737787643786 second(s).
# 1.0 hour(s), 41.0 minute(s), and 27.129153722853516 second(s).
# 1.0 hour(s), 41.0 minute(s), and 24.806045374780297 second(s).
# 1.0 hour(s), 41.0 minute(s), and 23.404958446508317 second(s).
# 1.0 hour(s), 41.0 minute(s), and 21.627543031609093 second(s).
# 1.0 hour(s), 41.0 minute(s), and 19.75586355422729 second(s).
# 1.0 hour(s), 41.0 minute(s), and 18.329129919409752 second(s).
# 1.0 hour(s), 41.0 minute(s), and 16.085652687247602 second(s).
# 1.0 hour(s), 41.0 minute(s), and 15.353672292744704 second(s).
# 1.0 hour(s), 41.0 minute(s), and 13.7986001634672 second(s).
# 1.0 hour(s), 41.0 minute(s), and 13.753992590104644 second(s).
# 1.0 hour(s), 41.0 minute(s), and 12.22444535595514 second(s).
# 1.0 hour(s), 41.0 minute(s), and 10.749358583161666 second(s).
# 1.0 hour(s), 41.0 minute(s), and 8.917658434033001 second(s).
# 1.0 hour(s), 41.0 minute(s), and 8.048753526475593 second(s).
# 1.0 hour(s), 41.0 minute(s), and 6.493549117321891 second(s).
# 1.0 hour(s), 41.0 minute(s), and 5.226920457987035 second(s).
# 1.0 hour(s), 41.0 minute(s), and 3.3848109113450846 second(s).
# 1.0 hour(s), 41.0 minute(s), and 2.4120088676736486 second(s).
# 1.0 hour(s), 41.0 minute(s), and 1.3311283931616344 second(s).
# 1.0 hour(s), 40.0 minute(s), and 59.75028961368298 second(s).
# 1.0 hour(s), 40.0 minute(s), and 58.276303600719075 second(s).
# 1.0 hour(s), 40.0 minute(s), and 56.76952285592142 second(s).
# 1.0 hour(s), 40.0 minute(s), and 55.88511653868227 second(s).
# 1.0 hour(s), 40.0 minute(s), and 54.05435348644096 second(s).
# 1.0 hour(s), 40.0 minute(s), and 52.95699514206626 second(s).
# 1.0 hour(s), 40.0 minute(s), and 51.88826909209729 second(s).
# 1.0 hour(s), 40.0 minute(s), and 50.78878619234456 second(s).
# 1.0 hour(s), 40.0 minute(s), and 49.1963562115443 second(s).
# 1.0 hour(s), 40.0 minute(s), and 47.30342251035381 second(s).
# 1.0 hour(s), 40.0 minute(s), and 45.90243525677397 second(s).
# 1.0 hour(s), 40.0 minute(s), and 44.51456983286607 second(s).
# 1.0 hour(s), 40.0 minute(s), and 42.98981388051925 second(s).
# 1.0 hour(s), 40.0 minute(s), and 41.79718262073402 second(s).
# 1.0 hour(s), 40.0 minute(s), and 40.441609121368856 second(s).
# 1.0 hour(s), 40.0 minute(s), and 38.31469375313918 second(s).
# 1.0 hour(s), 40.0 minute(s), and 37.36763454907032 second(s).
# 1.0 hour(s), 40.0 minute(s), and 36.02511332607173 second(s).
# 1.0 hour(s), 40.0 minute(s), and 34.60506025666291 second(s).
# 1.0 hour(s), 40.0 minute(s), and 32.831133597673215 second(s).
# 1.0 hour(s), 40.0 minute(s), and 32.317720996874414 second(s).
# 1.0 hour(s), 40.0 minute(s), and 30.832879613947625 second(s).
# 1.0 hour(s), 40.0 minute(s), and 29.777108804713862 second(s).
# 1.0 hour(s), 40.0 minute(s), and 27.70412514304735 second(s).
# 1.0 hour(s), 40.0 minute(s), and 26.265143535129937 second(s).
# 1.0 hour(s), 40.0 minute(s), and 24.100148841805094 second(s).
# 1.0 hour(s), 40.0 minute(s), and 22.211216926573798 second(s).
# 1.0 hour(s), 40.0 minute(s), and 21.158761739030524 second(s).
# 1.0 hour(s), 40.0 minute(s), and 20.260415967259178 second(s).
# 1.0 hour(s), 40.0 minute(s), and 18.215220888047952 second(s).
# 1.0 hour(s), 40.0 minute(s), and 16.639610607024224 second(s).
# 1.0 hour(s), 40.0 minute(s), and 15.234859544865685 second(s).
# 1.0 hour(s), 40.0 minute(s), and 14.069398170309796 second(s).
# 1.0 hour(s), 40.0 minute(s), and 11.866301574387762 second(s).
# 1.0 hour(s), 40.0 minute(s), and 10.870371973792317 second(s).
# 1.0 hour(s), 40.0 minute(s), and 9.735382105684948 second(s).
# 1.0 hour(s), 40.0 minute(s), and 8.411915962246894 second(s).
# 1.0 hour(s), 40.0 minute(s), and 6.732427119519343 second(s).
# 1.0 hour(s), 40.0 minute(s), and 5.465167340516018 second(s).
# 1.0 hour(s), 40.0 minute(s), and 4.6454334523941725 second(s).
# 1.0 hour(s), 40.0 minute(s), and 2.9977401848827867 second(s).
# 1.0 hour(s), 40.0 minute(s), and 1.338460726703488 second(s).
# 1.0 hour(s), 40.0 minute(s), and 0.648823080391594 second(s).
# 1.0 hour(s), 39.0 minute(s), and 58.97733712846184 second(s).
# 1.0 hour(s), 39.0 minute(s), and 57.60906540903488 second(s).
# 1.0 hour(s), 39.0 minute(s), and 55.79729435645095 second(s).
# 1.0 hour(s), 39.0 minute(s), and 54.41732597351165 second(s).
# 1.0 hour(s), 39.0 minute(s), and 53.16618260847554 second(s).
# 1.0 hour(s), 39.0 minute(s), and 51.050468726714826 second(s).
# 1.0 hour(s), 39.0 minute(s), and 49.66523842180777 second(s).
# 1.0 hour(s), 39.0 minute(s), and 47.75468804077718 second(s).
# 1.0 hour(s), 39.0 minute(s), and 47.50149557945588 second(s).
# 1.0 hour(s), 39.0 minute(s), and 45.9629824141266 second(s).
# 1.0 hour(s), 39.0 minute(s), and 44.77146023739533 second(s).
# 1.0 hour(s), 39.0 minute(s), and 43.397164747540046 second(s).
# 1.0 hour(s), 39.0 minute(s), and 42.568018509402464 second(s).
# 1.0 hour(s), 39.0 minute(s), and 41.640219261948005 second(s).
# 1.0 hour(s), 39.0 minute(s), and 39.666334658903 second(s).
# 1.0 hour(s), 39.0 minute(s), and 38.42975129974002 second(s).
# 1.0 hour(s), 39.0 minute(s), and 37.18065387938532 second(s).
# 1.0 hour(s), 39.0 minute(s), and 35.708833066689294 second(s).
# 1.0 hour(s), 39.0 minute(s), and 33.973254955732045 second(s).
# 1.0 hour(s), 39.0 minute(s), and 33.346734136176565 second(s).
# 1.0 hour(s), 39.0 minute(s), and 31.488686428908295 second(s).
# 1.0 hour(s), 39.0 minute(s), and 30.530890070959686 second(s).
# 1.0 hour(s), 39.0 minute(s), and 28.755726480019803 second(s).
# 1.0 hour(s), 39.0 minute(s), and 27.37397576703006 second(s).
# 1.0 hour(s), 39.0 minute(s), and 25.86741820916086 second(s).
# 1.0 hour(s), 39.0 minute(s), and 24.598442757888733 second(s).
# 1.0 hour(s), 39.0 minute(s), and 23.186943830131895 second(s).
# 1.0 hour(s), 39.0 minute(s), and 22.153822640687395 second(s).
# 1.0 hour(s), 39.0 minute(s), and 20.69461354716077 second(s).
# 1.0 hour(s), 39.0 minute(s), and 19.40649687685527 second(s).
# 1.0 hour(s), 39.0 minute(s), and 18.847528492732636 second(s).
# 1.0 hour(s), 39.0 minute(s), and 17.01132038661399 second(s).
# 1.0 hour(s), 39.0 minute(s), and 15.645605433952369 second(s).
# 1.0 hour(s), 39.0 minute(s), and 13.653342253541268 second(s).
# 1.0 hour(s), 39.0 minute(s), and 12.002034701988123 second(s).
# 1.0 hour(s), 39.0 minute(s), and 10.64921816711194 second(s).
# 1.0 hour(s), 39.0 minute(s), and 9.744951536677945 second(s).
# 1.0 hour(s), 39.0 minute(s), and 8.234055045514651 second(s).
# 1.0 hour(s), 39.0 minute(s), and 6.479581798825166 second(s).
# 1.0 hour(s), 39.0 minute(s), and 4.494334601838091 second(s).
# 1.0 hour(s), 39.0 minute(s), and 3.3331105809356814 second(s).
# 1.0 hour(s), 39.0 minute(s), and 1.9514824601046712 second(s).
# 1.0 hour(s), 39.0 minute(s), and 0.7141330380882209 second(s).
# 1.0 hour(s), 38.0 minute(s), and 59.45325267637145 second(s).
# 1.0 hour(s), 38.0 minute(s), and 58.35871667482297 second(s).
# 1.0 hour(s), 38.0 minute(s), and 56.72903497328389 second(s).
# 1.0 hour(s), 38.0 minute(s), and 55.13457406481666 second(s).
# 1.0 hour(s), 38.0 minute(s), and 53.9987529529044 second(s).
# 1.0 hour(s), 38.0 minute(s), and 53.46238694414933 second(s).
# 1.0 hour(s), 38.0 minute(s), and 52.55804900892963 second(s).
# 1.0 hour(s), 38.0 minute(s), and 51.13353575664314 second(s).
# 1.0 hour(s), 38.0 minute(s), and 49.384823154000514 second(s).
# 1.0 hour(s), 38.0 minute(s), and 48.108715142045185 second(s).
# 1.0 hour(s), 38.0 minute(s), and 46.70188085238169 second(s).
# 1.0 hour(s), 38.0 minute(s), and 44.84195925583117 second(s).
# 1.0 hour(s), 38.0 minute(s), and 43.882531178758654 second(s).
# 1.0 hour(s), 38.0 minute(s), and 42.90480936982567 second(s).
# 1.0 hour(s), 38.0 minute(s), and 41.41283917110832 second(s).
# 1.0 hour(s), 38.0 minute(s), and 40.044994472667895 second(s).
# 1.0 hour(s), 38.0 minute(s), and 39.081609078815745 second(s).
# 1.0 hour(s), 38.0 minute(s), and 38.30766820498138 second(s).
# 1.0 hour(s), 38.0 minute(s), and 36.75880111805054 second(s).
# 1.0 hour(s), 38.0 minute(s), and 35.450842311416636 second(s).
# 1.0 hour(s), 38.0 minute(s), and 34.622898151999834 second(s).
# 1.0 hour(s), 38.0 minute(s), and 32.38815502644229 second(s).
# 1.0 hour(s), 38.0 minute(s), and 31.411554171970238 second(s).
# 1.0 hour(s), 38.0 minute(s), and 29.635823538544173 second(s).
# 1.0 hour(s), 38.0 minute(s), and 28.144351760754034 second(s).
# 1.0 hour(s), 38.0 minute(s), and 26.398238370620675 second(s).
# 1.0 hour(s), 38.0 minute(s), and 25.317139078992113 second(s).
# 1.0 hour(s), 38.0 minute(s), and 24.030673755350108 second(s).
# 1.0 hour(s), 38.0 minute(s), and 23.014144753416076 second(s).
# 1.0 hour(s), 38.0 minute(s), and 22.211205570223683 second(s).
# ...
# 0.0 hour(s), 5.0 minute(s), and 59.55296645876575 second(s).
# 0.0 hour(s), 5.0 minute(s), and 58.16751088174976 second(s).
# 0.0 hour(s), 5.0 minute(s), and 56.783091485437524 second(s).
# 0.0 hour(s), 5.0 minute(s), and 55.39171668530315 second(s).
# 0.0 hour(s), 5.0 minute(s), and 53.99830561870016 second(s).
# 0.0 hour(s), 5.0 minute(s), and 52.604508692033676 second(s).
# 0.0 hour(s), 5.0 minute(s), and 51.2206802972874 second(s).
# 0.0 hour(s), 5.0 minute(s), and 49.829431214850786 second(s).
# 0.0 hour(s), 5.0 minute(s), and 48.443338917691904 second(s).
# 0.0 hour(s), 5.0 minute(s), and 47.05965211516934 second(s).
# 0.0 hour(s), 5.0 minute(s), and 45.673776363127104 second(s).
# 0.0 hour(s), 5.0 minute(s), and 44.28970891297462 second(s).
# 0.0 hour(s), 5.0 minute(s), and 42.89958330753751 second(s).
# 0.0 hour(s), 5.0 minute(s), and 41.51145028526361 second(s).
# 0.0 hour(s), 5.0 minute(s), and 40.12262625573936 second(s).
# 0.0 hour(s), 5.0 minute(s), and 38.73538001231327 second(s).
# 0.0 hour(s), 5.0 minute(s), and 37.34802772559266 second(s).
# 0.0 hour(s), 5.0 minute(s), and 35.95691427066072 second(s).
# 0.0 hour(s), 5.0 minute(s), and 34.566281731576055 second(s).
# 0.0 hour(s), 5.0 minute(s), and 33.178243701197516 second(s).
# 0.0 hour(s), 5.0 minute(s), and 31.788145651864397 second(s).
# 0.0 hour(s), 5.0 minute(s), and 30.3980372486771 second(s).
# 0.0 hour(s), 5.0 minute(s), and 29.008368574218935 second(s).
# 0.0 hour(s), 5.0 minute(s), and 27.619158892947837 second(s).
# 0.0 hour(s), 5.0 minute(s), and 26.22556467446549 second(s).
# 0.0 hour(s), 5.0 minute(s), and 24.839531873686212 second(s).
# 0.0 hour(s), 5.0 minute(s), and 23.450117334270203 second(s).
# 0.0 hour(s), 5.0 minute(s), and 22.063628031903477 second(s).
# 0.0 hour(s), 5.0 minute(s), and 20.67315756227265 second(s).
# 0.0 hour(s), 5.0 minute(s), and 19.28303540327761 second(s).
# 0.0 hour(s), 5.0 minute(s), and 17.901338528397446 second(s).
# 0.0 hour(s), 5.0 minute(s), and 16.510437927222085 second(s).
# 0.0 hour(s), 5.0 minute(s), and 15.119510339736564 second(s).
# 0.0 hour(s), 5.0 minute(s), and 13.731796701332996 second(s).
# 0.0 hour(s), 5.0 minute(s), and 12.348181913036285 second(s).
# 0.0 hour(s), 5.0 minute(s), and 10.965698143145914 second(s).
# 0.0 hour(s), 5.0 minute(s), and 9.577179989955482 second(s).
# 0.0 hour(s), 5.0 minute(s), and 8.189687624293015 second(s).
# 0.0 hour(s), 5.0 minute(s), and 6.802604733563101 second(s).
# 0.0 hour(s), 5.0 minute(s), and 5.414696690427661 second(s).
# 0.0 hour(s), 5.0 minute(s), and 4.027137235526936 second(s).
# 0.0 hour(s), 5.0 minute(s), and 2.6465525020869336 second(s).
# 0.0 hour(s), 5.0 minute(s), and 1.2552680462293324 second(s).
# 0.0 hour(s), 4.0 minute(s), and 59.866746315589296 second(s).
# 0.0 hour(s), 4.0 minute(s), and 58.47717037021556 second(s).
# 0.0 hour(s), 4.0 minute(s), and 57.090650481954526 second(s).
# 0.0 hour(s), 4.0 minute(s), and 55.700238838259565 second(s).
# 0.0 hour(s), 4.0 minute(s), and 54.30992860582933 second(s).
# 0.0 hour(s), 4.0 minute(s), and 52.91970074617382 second(s).
# 0.0 hour(s), 4.0 minute(s), and 51.531501055261515 second(s).
# 0.0 hour(s), 4.0 minute(s), and 50.14528455567046 second(s).
# 0.0 hour(s), 4.0 minute(s), and 48.76298263116752 second(s).
# 0.0 hour(s), 4.0 minute(s), and 47.373492023279766 second(s).
# 0.0 hour(s), 4.0 minute(s), and 45.981797783286254 second(s).
# 0.0 hour(s), 4.0 minute(s), and 44.59101260566115 second(s).
# 0.0 hour(s), 4.0 minute(s), and 43.20659673005167 second(s).
# 0.0 hour(s), 4.0 minute(s), and 41.81866838138302 second(s).
# 0.0 hour(s), 4.0 minute(s), and 40.43136866910601 second(s).
# 0.0 hour(s), 4.0 minute(s), and 39.04192090267986 second(s).
# 0.0 hour(s), 4.0 minute(s), and 37.65561319390929 second(s).
# 0.0 hour(s), 4.0 minute(s), and 36.263435262413054 second(s).
# 0.0 hour(s), 4.0 minute(s), and 34.87872689408789 second(s).
# 0.0 hour(s), 4.0 minute(s), and 33.48577042790521 second(s).
# 0.0 hour(s), 4.0 minute(s), and 32.09809056368596 second(s).
# 0.0 hour(s), 4.0 minute(s), and 30.708414176252234 second(s).
# 0.0 hour(s), 4.0 minute(s), and 29.31616716835333 second(s).
# 0.0 hour(s), 4.0 minute(s), and 27.925972374258833 second(s).
# 0.0 hour(s), 4.0 minute(s), and 26.53531915534552 second(s).
# 0.0 hour(s), 4.0 minute(s), and 25.144665404698742 second(s).
# 0.0 hour(s), 4.0 minute(s), and 23.76039104699595 second(s).
# 0.0 hour(s), 4.0 minute(s), and 22.369906228635784 second(s).
# 0.0 hour(s), 4.0 minute(s), and 20.979323271801377 second(s).
# 0.0 hour(s), 4.0 minute(s), and 19.590633347949392 second(s).
# 0.0 hour(s), 4.0 minute(s), and 18.202181010608854 second(s).
# 0.0 hour(s), 4.0 minute(s), and 16.815769895957658 second(s).
# 0.0 hour(s), 4.0 minute(s), and 15.428574055928323 second(s).
# 0.0 hour(s), 4.0 minute(s), and 14.03965814914946 second(s).
# 0.0 hour(s), 4.0 minute(s), and 12.65161768823009 second(s).
# 0.0 hour(s), 4.0 minute(s), and 11.266432615008227 second(s).
# 0.0 hour(s), 4.0 minute(s), and 9.880914050019129 second(s).
# 0.0 hour(s), 4.0 minute(s), and 8.493108018902035 second(s).
# 0.0 hour(s), 4.0 minute(s), and 7.102293786247088 second(s).
# 0.0 hour(s), 4.0 minute(s), and 5.712060649390509 second(s).
# 0.0 hour(s), 4.0 minute(s), and 4.323530970521205 second(s).
# 0.0 hour(s), 4.0 minute(s), and 2.9370743870117337 second(s).
# 0.0 hour(s), 4.0 minute(s), and 1.5500197458998457 second(s).
# 0.0 hour(s), 4.0 minute(s), and 0.16209034739949857 second(s).
# 0.0 hour(s), 3.0 minute(s), and 58.779149675922355 second(s).
# 0.0 hour(s), 3.0 minute(s), and 57.39332187973113 second(s).
# 0.0 hour(s), 3.0 minute(s), and 56.00481069359472 second(s).
# 0.0 hour(s), 3.0 minute(s), and 54.61497197677272 second(s).
# 0.0 hour(s), 3.0 minute(s), and 53.22449132069849 second(s).
# 0.0 hour(s), 3.0 minute(s), and 51.83455684514067 second(s).
# 0.0 hour(s), 3.0 minute(s), and 50.441927999122385 second(s).
# 0.0 hour(s), 3.0 minute(s), and 49.05082273212068 second(s).
# 0.0 hour(s), 3.0 minute(s), and 47.66443805461881 second(s).
# 0.0 hour(s), 3.0 minute(s), and 46.27516360388378 second(s).
# 0.0 hour(s), 3.0 minute(s), and 44.88891926330197 second(s).
# 0.0 hour(s), 3.0 minute(s), and 43.49951965174759 second(s).
# 0.0 hour(s), 3.0 minute(s), and 42.112815573195746 second(s).
# 0.0 hour(s), 3.0 minute(s), and 40.72192799584528 second(s).
# 0.0 hour(s), 3.0 minute(s), and 39.33269753568379 second(s).
# 0.0 hour(s), 3.0 minute(s), and 37.946498350936594 second(s).
# 0.0 hour(s), 3.0 minute(s), and 36.55830428031334 second(s).
# 0.0 hour(s), 3.0 minute(s), and 35.169632387112046 second(s).
# 0.0 hour(s), 3.0 minute(s), and 33.778639577707395 second(s).
# 0.0 hour(s), 3.0 minute(s), and 32.392144444162426 second(s).
# 0.0 hour(s), 3.0 minute(s), and 31.004716618226297 second(s).
# 0.0 hour(s), 3.0 minute(s), and 29.621953879122515 second(s).
# 0.0 hour(s), 3.0 minute(s), and 28.234535524525626 second(s).
# 0.0 hour(s), 3.0 minute(s), and 26.845623861069896 second(s).
# 0.0 hour(s), 3.0 minute(s), and 25.455592792877354 second(s).
# 0.0 hour(s), 3.0 minute(s), and 24.06995836351672 second(s).
# 0.0 hour(s), 3.0 minute(s), and 22.680066012432405 second(s).
# 0.0 hour(s), 3.0 minute(s), and 21.290174085251692 second(s).
# 0.0 hour(s), 3.0 minute(s), and 19.901844221834665 second(s).
# 0.0 hour(s), 3.0 minute(s), and 18.514202195281996 second(s).
# 0.0 hour(s), 3.0 minute(s), and 17.12897719125681 second(s).
# 0.0 hour(s), 3.0 minute(s), and 15.741351184591792 second(s).
# 0.0 hour(s), 3.0 minute(s), and 14.35285634464688 second(s).
# 0.0 hour(s), 3.0 minute(s), and 12.967227436735442 second(s).
# 0.0 hour(s), 3.0 minute(s), and 11.579070000823066 second(s).
# 0.0 hour(s), 3.0 minute(s), and 10.190111591079074 second(s).
# 0.0 hour(s), 3.0 minute(s), and 8.799734266965032 second(s).
# 0.0 hour(s), 3.0 minute(s), and 7.412907277692369 second(s).
# 0.0 hour(s), 3.0 minute(s), and 6.0242510092782595 second(s).
# 0.0 hour(s), 3.0 minute(s), and 4.634046927256719 second(s).
# 0.0 hour(s), 3.0 minute(s), and 3.2456271434868427 second(s).
# 0.0 hour(s), 3.0 minute(s), and 1.8558691347078593 second(s).
# 0.0 hour(s), 3.0 minute(s), and 0.467337505528576 second(s).
# 0.0 hour(s), 2.0 minute(s), and 59.080056792141534 second(s).
# 0.0 hour(s), 2.0 minute(s), and 57.69170939002328 second(s).
# 0.0 hour(s), 2.0 minute(s), and 56.303020125954106 second(s).
# 0.0 hour(s), 2.0 minute(s), and 54.915274798307564 second(s).
# 0.0 hour(s), 2.0 minute(s), and 53.52554544424399 second(s).
# 0.0 hour(s), 2.0 minute(s), and 52.1377387981712 second(s).
# 0.0 hour(s), 2.0 minute(s), and 50.749406784412315 second(s).
# 0.0 hour(s), 2.0 minute(s), and 49.36157751435283 second(s).
# 0.0 hour(s), 2.0 minute(s), and 47.976671034010934 second(s).
# 0.0 hour(s), 2.0 minute(s), and 46.58794283866882 second(s).
# 0.0 hour(s), 2.0 minute(s), and 45.20071160004437 second(s).
# 0.0 hour(s), 2.0 minute(s), and 43.81453931795579 second(s).
# 0.0 hour(s), 2.0 minute(s), and 42.42335508852591 second(s).
# 0.0 hour(s), 2.0 minute(s), and 41.03542125039564 second(s).
# 0.0 hour(s), 2.0 minute(s), and 39.645806065113305 second(s).
# 0.0 hour(s), 2.0 minute(s), and 38.259505538241655 second(s).
# 0.0 hour(s), 2.0 minute(s), and 36.87327861883463 second(s).
# 0.0 hour(s), 2.0 minute(s), and 35.48593732534181 second(s).
# 0.0 hour(s), 2.0 minute(s), and 34.09703397087634 second(s).
# 0.0 hour(s), 2.0 minute(s), and 32.708885357667555 second(s).
# 0.0 hour(s), 2.0 minute(s), and 31.318793989451365 second(s).
# 0.0 hour(s), 2.0 minute(s), and 29.93085544243857 second(s).
# 0.0 hour(s), 2.0 minute(s), and 28.54464301984052 second(s).
# 0.0 hour(s), 2.0 minute(s), and 27.15557342487594 second(s).
# 0.0 hour(s), 2.0 minute(s), and 25.767514684714115 second(s).
# 0.0 hour(s), 2.0 minute(s), and 24.37684133512522 second(s).
# 0.0 hour(s), 2.0 minute(s), and 22.98765591750322 second(s).
# 0.0 hour(s), 2.0 minute(s), and 21.598666012360155 second(s).
# 0.0 hour(s), 2.0 minute(s), and 20.210548119876876 second(s).
# 0.0 hour(s), 2.0 minute(s), and 18.824467367055462 second(s).
# 0.0 hour(s), 2.0 minute(s), and 17.435515721071454 second(s).
# 0.0 hour(s), 2.0 minute(s), and 16.04797937158952 second(s).
# 0.0 hour(s), 2.0 minute(s), and 14.659795067783477 second(s).
# 0.0 hour(s), 2.0 minute(s), and 13.271863887593952 second(s).
# 0.0 hour(s), 2.0 minute(s), and 11.882188783144016 second(s).
# 0.0 hour(s), 2.0 minute(s), and 10.493572522026142 second(s).
# 0.0 hour(s), 2.0 minute(s), and 9.106785656795097 second(s).
# 0.0 hour(s), 2.0 minute(s), and 7.72129931834624 second(s).
# 0.0 hour(s), 2.0 minute(s), and 6.331558496700964 second(s).
# 0.0 hour(s), 2.0 minute(s), and 4.9433817028270965 second(s).
# 0.0 hour(s), 2.0 minute(s), and 3.55637384805776 second(s).
# 0.0 hour(s), 2.0 minute(s), and 2.1694597425212265 second(s).
# 0.0 hour(s), 2.0 minute(s), and 0.7809752576006161 second(s).
# 0.0 hour(s), 1.0 minute(s), and 59.394054376064986 second(s).
# 0.0 hour(s), 1.0 minute(s), and 58.00543939982401 second(s).
# 0.0 hour(s), 1.0 minute(s), and 56.61876452793621 second(s).
# 0.0 hour(s), 1.0 minute(s), and 55.229076654609926 second(s).
# 0.0 hour(s), 1.0 minute(s), and 53.84255982628193 second(s).
# 0.0 hour(s), 1.0 minute(s), and 52.45415275996962 second(s).
# 0.0 hour(s), 1.0 minute(s), and 51.06512932661103 second(s).
# 0.0 hour(s), 1.0 minute(s), and 49.67689107293353 second(s).
# 0.0 hour(s), 1.0 minute(s), and 48.28816030888673 second(s).
# 0.0 hour(s), 1.0 minute(s), and 46.899440060682764 second(s).
# 0.0 hour(s), 1.0 minute(s), and 45.51082625416214 second(s).
# 0.0 hour(s), 1.0 minute(s), and 44.12381709892739 second(s).
# 0.0 hour(s), 1.0 minute(s), and 42.734281015841404 second(s).
# 0.0 hour(s), 1.0 minute(s), and 41.34452159147803 second(s).
# 0.0 hour(s), 1.0 minute(s), and 39.95714710904406 second(s).
# 0.0 hour(s), 1.0 minute(s), and 38.56883875577343 second(s).
# 0.0 hour(s), 1.0 minute(s), and 37.18024658479749 second(s).
# 0.0 hour(s), 1.0 minute(s), and 35.79040252734477 second(s).
# 0.0 hour(s), 1.0 minute(s), and 34.40103196111619 second(s).
# 0.0 hour(s), 1.0 minute(s), and 33.01030766270404 second(s).
# 0.0 hour(s), 1.0 minute(s), and 31.620555259169564 second(s).
# 0.0 hour(s), 1.0 minute(s), and 30.232181615017822 second(s).
# 0.0 hour(s), 1.0 minute(s), and 28.843735826266652 second(s).
# 0.0 hour(s), 1.0 minute(s), and 27.455885746567418 second(s).
# 0.0 hour(s), 1.0 minute(s), and 26.06742173411577 second(s).
# 0.0 hour(s), 1.0 minute(s), and 24.679195738195958 second(s).
# 0.0 hour(s), 1.0 minute(s), and 23.290928250864937 second(s).
# 0.0 hour(s), 1.0 minute(s), and 21.90179110712137 second(s).
# 0.0 hour(s), 1.0 minute(s), and 20.513391533249163 second(s).
# 0.0 hour(s), 1.0 minute(s), and 19.124492263205497 second(s).
# 0.0 hour(s), 1.0 minute(s), and 17.736151995010744 second(s).
# 0.0 hour(s), 1.0 minute(s), and 16.34776298148809 second(s).
# 0.0 hour(s), 1.0 minute(s), and 14.958235486914077 second(s).
# 0.0 hour(s), 1.0 minute(s), and 13.570250432323107 second(s).
# 0.0 hour(s), 1.0 minute(s), and 12.18207106806139 second(s).
# 0.0 hour(s), 1.0 minute(s), and 10.795028696351153 second(s).
# 0.0 hour(s), 1.0 minute(s), and 9.407266383219252 second(s).
# 0.0 hour(s), 1.0 minute(s), and 8.019518616030467 second(s).
# 0.0 hour(s), 1.0 minute(s), and 6.632724654116032 second(s).
# 0.0 hour(s), 1.0 minute(s), and 5.24419238724758 second(s).
# 0.0 hour(s), 1.0 minute(s), and 3.8558982227134493 second(s).
# 0.0 hour(s), 1.0 minute(s), and 2.4682183487023153 second(s).
# 0.0 hour(s), 1.0 minute(s), and 1.079912157959285 second(s).
# 0.0 hour(s), 0.0 minute(s), and 59.69068259276136 second(s).
# 0.0 hour(s), 0.0 minute(s), and 58.302629971706175 second(s).
# 0.0 hour(s), 0.0 minute(s), and 56.91484550305686 second(s).
# 0.0 hour(s), 0.0 minute(s), and 55.526655222139055 second(s).
# 0.0 hour(s), 0.0 minute(s), and 54.13838743005302 second(s).
# 0.0 hour(s), 0.0 minute(s), and 52.74964196092897 second(s).
# 0.0 hour(s), 0.0 minute(s), and 51.3614869975717 second(s).
# 0.0 hour(s), 0.0 minute(s), and 49.97395664679246 second(s).
# 0.0 hour(s), 0.0 minute(s), and 48.58584137337446 second(s).
# 0.0 hour(s), 0.0 minute(s), and 47.19749367837218 second(s).
# 0.0 hour(s), 0.0 minute(s), and 45.808732923473514 second(s).
# 0.0 hour(s), 0.0 minute(s), and 44.419861841125 second(s).
# 0.0 hour(s), 0.0 minute(s), and 43.03241129784211 second(s).
# 0.0 hour(s), 0.0 minute(s), and 41.64483774595817 second(s).
# 0.0 hour(s), 0.0 minute(s), and 40.25636185157997 second(s).
# 0.0 hour(s), 0.0 minute(s), and 38.867947235283886 second(s).
# 0.0 hour(s), 0.0 minute(s), and 37.48001894436922 second(s).
# 0.0 hour(s), 0.0 minute(s), and 36.09179263935542 second(s).
# 0.0 hour(s), 0.0 minute(s), and 34.70352671493837 second(s).
# 0.0 hour(s), 0.0 minute(s), and 33.31547018607713 second(s).
# 0.0 hour(s), 0.0 minute(s), and 31.92720552105872 second(s).
# 0.0 hour(s), 0.0 minute(s), and 30.539473728464998 second(s).
# 0.0 hour(s), 0.0 minute(s), and 29.151136968719552 second(s).
# 0.0 hour(s), 0.0 minute(s), and 27.762756275843426 second(s).
# 0.0 hour(s), 0.0 minute(s), and 26.374851895154084 second(s).
# 0.0 hour(s), 0.0 minute(s), and 24.9864111447229 second(s).
# 0.0 hour(s), 0.0 minute(s), and 23.598267412223944 second(s).
# 0.0 hour(s), 0.0 minute(s), and 22.210076659678645 second(s).
# 0.0 hour(s), 0.0 minute(s), and 20.82193526915586 second(s).
# 0.0 hour(s), 0.0 minute(s), and 19.43372516444635 second(s).
# 0.0 hour(s), 0.0 minute(s), and 18.045640627798107 second(s).
# 0.0 hour(s), 0.0 minute(s), and 16.657464648402016 second(s).
# 0.0 hour(s), 0.0 minute(s), and 15.269250249212742 second(s).
# 0.0 hour(s), 0.0 minute(s), and 13.881033417695988 second(s).
# 0.0 hour(s), 0.0 minute(s), and 12.49289609773965 second(s).
# 0.0 hour(s), 0.0 minute(s), and 11.104832797478407 second(s).
# 0.0 hour(s), 0.0 minute(s), and 9.716514243598265 second(s).
# 0.0 hour(s), 0.0 minute(s), and 8.328758498693304 second(s).
# 0.0 hour(s), 0.0 minute(s), and 6.9406630558533235 second(s).
# 0.0 hour(s), 0.0 minute(s), and 5.552457636122326 second(s).
# 0.0 hour(s), 0.0 minute(s), and 4.164302463266213 second(s).
# 0.0 hour(s), 0.0 minute(s), and 2.776193917775545 second(s).
# 0.0 hour(s), 0.0 minute(s), and 1.3881106103842535 second(s).
# (1843709, 8, 8, 25)
# (1843709, 1968)

# %% [markdown]
# ### 4th approach: Self-play!
#
#
# Ok fellas, let's consider that we have ssome sort neural network configuration which is able to receive as an input a chess position and output a recommended move for this position. It doesnt need to be good but it needs to be able to give this output. This chapter is like a short introduction where the move predictions happen probabilistically from the policy probability distribution that the neural network outputs.

# %%
from tensorflow.keras import models
from   svglib.svglib import svg2rlg
from reportlab.graphics import renderPM
import glob
import os
import pickle
import tensorflow as tf
import chess
import numpy as np
import nbimporter
import chess.svg

from Board_to_NeuralNetwork import board_to_network_input
from Board_to_NeuralNetwork import all_possible_moves
model=tf.keras.models.load_model(r'C:\Users\45819\Downloads\supervised_model__.h5')




def choose_files_with_pattern(max_num=9999, pickles_path=''):
    """
    Finds files with a given file path pattern and returns them in a list.
    Stops after finding the specified maximum number of files.
    """
    files = []
    i = 1
    for file in glob.glob(pickles_path):
        files.append(file)
        if i >= max_num:
            break
        i += 1
    return files

def save_image(board, i, formatted_string):
    """
    Saves an SVG image and PNG image of the chess board at the current state.
    """
    boardsvg = chess.svg.board(board=board)
    outputfile = './supervised_game' + formatted_string + '/match%03d.SVG' % i
    outputpng = './supervised_game' + formatted_string + '/match%03d.png' % i
    with open(outputfile, "w") as f:
        f.write(boardsvg)
    drawing = svg2rlg(outputfile)
    renderPM.drawToFile(drawing, outputpng, dpi=200, fmt="PNG")
    os.remove(outputfile)



class Chess_object():
    def __init__(self):
        """
        Initializes a new chess board object using the chess library.
        Also initializes a variable n_moves to 64.
        """
        self.board = chess.Board()
        # List of all possible chess moves
        self.moves_list = all_possible_moves()
        self.n_moves = len(self.moves_list)
        self.legal_moves = None
        self.legal_moves_string = None
    def find_move_index(self, move):
        """
        Given a move, return its index in the list of all possible moves.
        """
        idx = np.where(self.moves_list == move)
        return idx

    def find_index_move(self, index):
        """
        Given an index, return the corresponding move.
        """
        return self.moves_list[index]

    def printboard(self):
        """
        Print the current state of the chess board.
        """
        print(self.board)

    def setstartingposition(self):
        """
        Set the chess board to the starting position.
        """
        self.board = chess.Board()

    def applymove(self, move_str):
        """
        Apply the move on the chess board and update the turn.
        Also reset the legal_moves variable.
        """
        move = chess.Move.from_uci(move_str)
        board = self.board.copy()
        board.push(move)
        self.legal_moves = None
        self.board = board

    def generatelegalmoves(self):
        """
        Generate a list of legal moves and set it to the legal_moves variable.
        If the legal_moves variable is already set, return it without regenerating it.
        """
        moves = list(self.board.legal_moves)
        self.legal_moves = moves
        self.legal_moves_string = [str(move) for move in self.legal_moves]
        return self.legal_moves

    def getlegalmovesidxs(self):
        """
        Return the indices of the legal moves in the list of all possible moves.
        """
        legal_moves = [str(move) for move in self.board.legal_moves]
        indices = [i for i, x in enumerate(self.moves_list) if x in legal_moves]
        return indices

    def isTerminal(self):
        """
        Determine if the current chess board state is a terminal state.
        Print the outcome of the game.
        Return a tuple (bool, winner) where bool is True if the game is over,
        and winner is the winner of the game ('White'/'Black') or None if the game is a draw.
        """
        winner = None
        self.result = self.board.result()
        print('result', self.result)
        if self.result=='*':
            return False, None 
        elif self.result=='1-0':
            return True, 1
        elif self.result=='0-1':
            return True, -1
        elif self.result=='1/2-1/2':
            return True, 0

    def toNetworkInput(self):
        """
        Converts the current chess board state to a format that can be used as input to a neural network.
        The method uses the split_dims_rami function which is not defined in the code snippet provided.
        """
        x=board_to_network_input(self.board)
        return np.expand_dims(x, axis=0)
    def getmovesprobabilities(self):
        
        x=self.toNetworkInput()
        moves_prob,evaluation=model.predict(x)

        return moves_prob,evaluation


import os
import pickle
import numpy as np


def play_n_games(games=3, save=False):
    """
    Play a number of chess games and save the training data.
    :param games: The number of games to play.
    :param save: Whether to save the training data or not.
    """
    for game in range(games):
        # Initialize board
        b = Chess_object()
        # Set starting position
        b.setstartingposition()
        i = 0
        if save:
            # Define output images folder location
            x = len(choose_files_with_pattern(max_num=9999, pickles_path='./supervised_game*')) + 2
            print('found n games:', x, '\n\n\n\n\n')
            formatted_string = "{:03d}".format(x)
            game_folder = './supervised_game' + formatted_string
            if not os.path.isdir(game_folder):
                os.mkdir(game_folder)
            
        # Initializing placeholders for the saved training data
        positions = []
        best_moves_probs = []
        outcomes = []
        evaluations = []
        
        while True:
            # Transform the board to a neural network-friendly input
            x = b.toNetworkInput()
            # Get the move probabilities and evaluation for all possible moves
            probs, evaluation = b.getmovesprobabilities()
            # Reshape probabilities to (n_moves,)
            probs = probs.reshape(b.n_moves)
            # Generate all legal moves of the given chess board
            b.generatelegalmoves()
            # Get the indexes of the legal moves
            legal_moves_idx = b.getlegalmovesidxs()
            # Set the probability of illegal moves to zero
            mask = np.zeros_like(probs, dtype=bool)
            mask[legal_moves_idx] = True
            probs[~mask] = 0
            probs /= np.sum(probs)

            # Choose the next move
            # Probabilistic move based on the probabilities
            idx = np.random.choice(len(probs), p=probs)
            # Find the string representation of the best move
            bm = b.find_index_move(idx)
        
            print('%2.2f'%(probs[idx]/np.sum(probs)*100),'%% move probability')
            
            positions.append(x)
            best_moves_probs.append(probs)
            evaluations.append(evaluation)
            print(bm)
            # Make the move!
            b.applymove(bm)
            if save:
                save_image(b.board, i, formatted_string)
            i += 1
            condition, score = b.isTerminal()
            if condition:
                print('game is over', score)
                break
        print('game lasted ', i, ' moves \n\n\n')
        
        # Save the training data
        x = len(choose_files_with_pattern(max_num=9999999, pickles_path='./selfplaydata/positions*')) + 1
        formatted_string = "{:05d}".format(x)
        
        with open("./selfplaydata/positions"+formatted_string, "ab") as f:
            pickle.dump(positions, f)
        with open("./selfplaydata/best_moves_probs"+formatted_string, "ab") as f:
            pickle.dump(best_moves_probs, f)
        with open("./selfplaydata/evaluations"+formatted_string, "ab") as f:
            pickle.dump(evaluations, f)
        print('score:',score)
        for k in range(i):
            outcomes.append(score)
        with open("./selfplaydata/outcomes"+formatted_string,"ab") as f:
            pickle.dump(outcomes,f)
        
        

play_n_games(1,save=False)
# Out:
# 1/1 [==============================] - 0s 455ms/step
# 3.38 %% move probability
# g1f3
# result *
# 1/1 [==============================] - 0s 19ms/step
# 16.80 %% move probability
# b8c6
# result *
# 1/1 [==============================] - 0s 20ms/step
# 43.36 %% move probability
# g2g3
# result *
# 1/1 [==============================] - 0s 22ms/step
# 76.04 %% move probability
# e7e5
# result *
# 1/1 [==============================] - 0s 19ms/step
# 40.78 %% move probability
# f1g2
# result *
# 1/1 [==============================] - 0s 18ms/step
# 70.52 %% move probability
# d7d5
# result *
# 1/1 [==============================] - 0s 19ms/step
# 39.61 %% move probability
# d2d3
# result *
# 1/1 [==============================] - 0s 22ms/step
# 97.73 %% move probability
# h7h6
# result *
# 1/1 [==============================] - 0s 22ms/step
# 100.00 %% move probability
# e1g1
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.99 %% move probability
# g7g5
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.84 %% move probability
# c2c4
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.94 %% move probability
# g5g4
# result *
# 1/1 [==============================] - 0s 23ms/step
# 99.80 %% move probability
# f3d2
# result *
# 1/1 [==============================] - 0s 23ms/step
# 100.00 %% move probability
# c8e6
# result *
# 1/1 [==============================] - 0s 21ms/step
# 99.99 %% move probability
# b1c3
# result *
# 1/1 [==============================] - 0s 19ms/step
# 100.00 %% move probability
# d5d4
# result *
# 1/1 [==============================] - 0s 21ms/step
# 99.97 %% move probability
# c3b5
# result *
# 1/1 [==============================] - 0s 22ms/step
# 99.99 %% move probability
# a7a6
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.99 %% move probability
# b5a3
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.17 %% move probability
# d8d7
# result *
# 1/1 [==============================] - 0s 19ms/step
# 100.00 %% move probability
# d1a4
# result *
# 1/1 [==============================] - 0s 21ms/step
# 99.98 %% move probability
# h6h5
# result *
# 1/1 [==============================] - 0s 24ms/step
# 100.00 %% move probability
# a1b1
# result *
# 1/1 [==============================] - 0s 20ms/step
# 100.00 %% move probability
# h5h4
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.90 %% move probability
# b2b4
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.99 %% move probability
# h4g3
# result *
# 1/1 [==============================] - 0s 22ms/step
# 100.00 %% move probability
# f2g3
# result *
# 1/1 [==============================] - 0s 22ms/step
# 99.97 %% move probability
# f7f5
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.71 %% move probability
# b4b5
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.92 %% move probability
# d7h7
# result *
# 1/1 [==============================] - 0s 19ms/step
# 100.00 %% move probability
# b5c6
# result *
# 1/1 [==============================] - 0s 21ms/step
# 99.96 %% move probability
# h7h2
# result *
# 1/1 [==============================] - 0s 22ms/step
# 100.00 %% move probability
# g1f2
# result *
# 1/1 [==============================] - 0s 19ms/step
# 100.00 %% move probability
# h2h6
# result *
# 1/1 [==============================] - 0s 20ms/step
# 100.00 %% move probability
# c6b7
# result *
# 1/1 [==============================] - 0s 20ms/step
# 100.00 %% move probability
# e6d7
# result *
# 1/1 [==============================] - 0s 22ms/step
# 100.00 %% move probability
# b7a8q
# result *
# 1/1 [==============================] - 0s 21ms/step
# 100.00 %% move probability
# e8e7
# result *
# 1/1 [==============================] - 0s 19ms/step
# 100.00 %% move probability
# a4b4
# result *
# 1/1 [==============================] - 0s 19ms/step
# 100.00 %% move probability
# e7e6
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.94 %% move probability
# g2d5
# result *
# 1/1 [==============================] - 0s 18ms/step
# 100.00 %% move probability
# e6f6
# result *
# 1/1 [==============================] - 0s 20ms/step
# 99.99 %% move probability
# b4f8
# result *
# 1/1 [==============================] - 0s 19ms/step
# 100.00 %% move probability
# f6g6
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.83 %% move probability
# f8h6
# result *
# 1/1 [==============================] - 0s 21ms/step
# 100.00 %% move probability
# h8h6
# result *
# 1/1 [==============================] - 0s 22ms/step
# 100.00 %% move probability
# a8g8
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.95 %% move probability
# g6f6
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.78 %% move probability
# g8f7
# result *
# 1/1 [==============================] - 0s 20ms/step
# 100.00 %% move probability
# f6g5
# result *
# 1/1 [==============================] - 0s 21ms/step
# 100.00 %% move probability
# f7d7
# result *
# 1/1 [==============================] - 0s 23ms/step
# 99.89 %% move probability
# h6h2
# result *
# 1/1 [==============================] - 0s 20ms/step
# 99.98 %% move probability
# f2g1
# result *
# 1/1 [==============================] - 0s 20ms/step
# 100.00 %% move probability
# h2e2
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.82 %% move probability
# d2e4
# result *
# 1/1 [==============================] - 0s 23ms/step
# 99.99 %% move probability
# g5h5
# result *
# 1/1 [==============================] - 0s 20ms/step
# 6.66 %% move probability
# d7b5
# result *
# 1/1 [==============================] - 0s 20ms/step
# 100.00 %% move probability
# a6b5
# result *
# 1/1 [==============================] - 0s 19ms/step
# 56.23 %% move probability
# e4c5
# result *
# 1/1 [==============================] - 0s 21ms/step
# 46.82 %% move probability
# e2e1
# result *
# 1/1 [==============================] - 0s 21ms/step
# 98.96 %% move probability
# c1f4
# result *
# 1/1 [==============================] - 0s 19ms/step
# 95.09 %% move probability
# e1b1
# result *
# 1/1 [==============================] - 0s 18ms/step
# 81.14 %% move probability
# f4g5
# result *
# 1/1 [==============================] - 0s 20ms/step
# 100.00 %% move probability
# h5g5
# result *
# 1/1 [==============================] - 0s 23ms/step
# 99.87 %% move probability
# f1b1
# result *
# 1/1 [==============================] - 0s 20ms/step
# 69.07 %% move probability
# g5h6
# result *
# 1/1 [==============================] - 0s 18ms/step
# 96.01 %% move probability
# b1b5
# result *
# 1/1 [==============================] - 0s 19ms/step
# 34.57 %% move probability
# h6g5
# result *
# 1/1 [==============================] - 0s 22ms/step
# 47.07 %% move probability
# d5f7
# result *
# 1/1 [==============================] - 0s 23ms/step
# 91.66 %% move probability
# c7c6
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.95 %% move probability
# b5b7
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.31 %% move probability
# g5f6
# result *
# 1/1 [==============================] - 0s 19ms/step
# 87.90 %% move probability
# b7b5
# result *
# 1/1 [==============================] - 0s 21ms/step
# 54.65 %% move probability
# f6e7
# result *
# 1/1 [==============================] - 0s 23ms/step
# 95.51 %% move probability
# b5b7
# result *
# 1/1 [==============================] - 0s 18ms/step
# 63.60 %% move probability
# e7d8
# result *
# 1/1 [==============================] - 0s 19ms/step
# 83.86 %% move probability
# f7e8
# result *
# 1/1 [==============================] - 0s 22ms/step
# 99.96 %% move probability
# d8e8
# result *
# 1/1 [==============================] - 0s 22ms/step
# 69.02 %% move probability
# b7g7
# result *
# 1/1 [==============================] - 0s 20ms/step
# 98.06 %% move probability
# e8f8
# result *
# 1/1 [==============================] - 0s 20ms/step
# 31.16 %% move probability
# g7g6
# result *
# 1/1 [==============================] - 0s 22ms/step
# 96.15 %% move probability
# f8f7
# result *
# 1/1 [==============================] - 0s 23ms/step
# 99.85 %% move probability
# g6d6
# result *
# 1/1 [==============================] - 0s 21ms/step
# 55.30 %% move probability
# f7e7
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.11 %% move probability
# d6c6
# result *
# 1/1 [==============================] - 0s 24ms/step
# 100.00 %% move probability
# e5e4
# result *
# 1/1 [==============================] - 0s 21ms/step
# 95.25 %% move probability
# c6e6
# result *
# 1/1 [==============================] - 0s 23ms/step
# 99.97 %% move probability
# e7f7
# result *
# 1/1 [==============================] - 0s 20ms/step
# 81.18 %% move probability
# e6c6
# result *
# 1/1 [==============================] - 0s 18ms/step
# 95.47 %% move probability
# e4e3
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.79 %% move probability
# c6d6
# result *
# 1/1 [==============================] - 0s 23ms/step
# 99.46 %% move probability
# f7e8
# result *
# 1/1 [==============================] - 0s 23ms/step
# 55.51 %% move probability
# d6f6
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.67 %% move probability
# e8e7
# result *
# 1/1 [==============================] - 0s 19ms/step
# 18.51 %% move probability
# f6e6
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.99 %% move probability
# e7f7
# result *
# 1/1 [==============================] - 0s 22ms/step
# 90.78 %% move probability
# e6c6
# result *
# 1/1 [==============================] - 0s 20ms/step
# 78.65 %% move probability
# f7e8
# result *
# 1/1 [==============================] - 0s 19ms/step
# 87.11 %% move probability
# c6d6
# result *
# 1/1 [==============================] - 0s 20ms/step
# 72.97 %% move probability
# e8e7
# result *
# 1/1 [==============================] - 0s 20ms/step
# 15.89 %% move probability
# d6d5
# result *
# 1/1 [==============================] - 0s 22ms/step
# 99.79 %% move probability
# f5f4
# result *
# 1/1 [==============================] - 0s 18ms/step
# 99.75 %% move probability
# g3f4
# result *
# 1/1 [==============================] - 0s 19ms/step
# 78.49 %% move probability
# g4g3
# result *
# 1/1 [==============================] - 0s 21ms/step
# 99.86 %% move probability
# d5d4
# result *
# 1/1 [==============================] - 0s 22ms/step
# 99.80 %% move probability
# e3e2
# result *
# 1/1 [==============================] - 0s 20ms/step
# 98.26 %% move probability
# g1g2
# result *
# 1/1 [==============================] - 0s 18ms/step
# 100.00 %% move probability
# e2e1q
# result *
# 1/1 [==============================] - 0s 19ms/step
# 92.38 %% move probability
# f4f5
# result *
# 1/1 [==============================] - 0s 23ms/step
# 36.61 %% move probability
# e1e6
# result *
# 1/1 [==============================] - 0s 23ms/step
# 85.97 %% move probability
# f5f6
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.99 %% move probability
# e6f6
# result *
# 1/1 [==============================] - 0s 19ms/step
# 58.53 %% move probability
# d4g4
# result *
# 1/1 [==============================] - 0s 22ms/step
# 84.42 %% move probability
# f6a6
# result *
# 1/1 [==============================] - 0s 20ms/step
# 23.79 %% move probability
# g2f3
# result *
# 1/1 [==============================] - 0s 19ms/step
# 18.66 %% move probability
# a6a4
# result *
# 1/1 [==============================] - 0s 19ms/step
# 89.35 %% move probability
# g4g7
# result *
# 1/1 [==============================] - 0s 20ms/step
# 93.93 %% move probability
# e7f6
# result *
# 1/1 [==============================] - 0s 22ms/step
# 91.90 %% move probability
# g7g6
# result *
# 1/1 [==============================] - 0s 21ms/step
# 66.54 %% move probability
# f6g6
# result *
# 1/1 [==============================] - 0s 19ms/step
# 93.51 %% move probability
# f3g3
# result *
# 1/1 [==============================] - 0s 21ms/step
# 76.53 %% move probability
# a4a5
# result *
# 1/1 [==============================] - 0s 23ms/step
# 24.68 %% move probability
# c5a6
# result *
# 1/1 [==============================] - 0s 21ms/step
# 80.46 %% move probability
# a5a4
# result *
# 1/1 [==============================] - 0s 19ms/step
# 87.64 %% move probability
# a6c5
# result *
# 1/1 [==============================] - 0s 19ms/step
# 76.53 %% move probability
# a4a5
# result *
# 1/1 [==============================] - 0s 21ms/step
# 69.46 %% move probability
# c5d7
# result *
# 1/1 [==============================] - 0s 22ms/step
# 81.65 %% move probability
# a5a3
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.76 %% move probability
# d7b6
# result *
# 1/1 [==============================] - 0s 19ms/step
# 89.54 %% move probability
# a3c1
# result *
# 1/1 [==============================] - 0s 19ms/step
# 95.47 %% move probability
# d3d4
# result *
# 1/1 [==============================] - 0s 21ms/step
# 98.81 %% move probability
# c1c3
# result *
# 1/1 [==============================] - 0s 21ms/step
# 99.75 %% move probability
# g3f4
# result *
# 1/1 [==============================] - 0s 19ms/step
# 42.39 %% move probability
# c3d4
# result *
# 1/1 [==============================] - 0s 19ms/step
# 98.81 %% move probability
# f4f3
# result *
# 1/1 [==============================] - 0s 20ms/step
# 69.08 %% move probability
# g6f5
# result *
# 1/1 [==============================] - 0s 22ms/step
# 85.49 %% move probability
# b6a4
# result *
# 1/1 [==============================] - 0s 20ms/step
# 26.12 %% move probability
# d4d1
# result *
# 1/1 [==============================] - 0s 19ms/step
# 99.39 %% move probability
# f3e3
# result *
# 1/1 [==============================] - 0s 19ms/step
# 56.06 %% move probability
# d1b3
# result *
# 1/1 [==============================] - 0s 21ms/step
# 100.00 %% move probability
# a2b3
# result *
# 1/1 [==============================] - 0s 21ms/step
# 99.96 %% move probability
# f5e5
# result *
# 1/1 [==============================] - 0s 19ms/step
# 88.68 %% move probability
# c4c5
# result *
# 1/1 [==============================] - 0s 19ms/step
# 35.47 %% move probability
# e5d5
# result *
# 1/1 [==============================] - 0s 21ms/step
# 95.05 %% move probability
# b3b4
# result *
# 1/1 [==============================] - 0s 22ms/step
# 85.50 %% move probability
# d5c4
# result *
# 1/1 [==============================] - 0s 20ms/step
# 99.99 %% move probability
# e3f3
# result *
# 1/1 [==============================] - 0s 19ms/step
# 95.84 %% move probability
# c4b4
# result *
# 1/1 [==============================] - 0s 19ms/step
# 14.84 %% move probability
# f3e3
# result *
# 1/1 [==============================] - 0s 23ms/step
# 96.27 %% move probability
# b4a4
# result *
# 1/1 [==============================] - 0s 20ms/step
# 98.24 %% move probability
# e3f3
# result *
# 1/1 [==============================] - 0s 18ms/step
# 99.88 %% move probability
# a4a5
# result *
# 1/1 [==============================] - 0s 19ms/step
# 100.00 %% move probability
# c5c6
# result *
# 1/1 [==============================] - 0s 20ms/step
# 4.35 %% move probability
# a5b4
# result *
# 1/1 [==============================] - 0s 21ms/step
# 99.72 %% move probability
# c6c7
# result *
# 1/1 [==============================] - 0s 19ms/step
# 10.68 %% move probability
# b4c4
# result *
# 1/1 [==============================] - 0s 18ms/step
# 46.15 %% move probability
# f3g2
# result *
# 1/1 [==============================] - 0s 22ms/step
# 99.45 %% move probability
# c4d4
# result *
# 1/1 [==============================] - 0s 22ms/step
# 87.42 %% move probability
# c7c8q
# result *
# 1/1 [==============================] - 0s 19ms/step
# 92.65 %% move probability
# d4d3
# result *
# 1/1 [==============================] - 0s 20ms/step
# 96.16 %% move probability
# c8c2
# result *
# 1/1 [==============================] - 0s 20ms/step
# 100.00 %% move probability
# d3c2
# result 1/2-1/2
# game is over 0
# game lasted  162  moves
#
#
#
# score: 0

# %% [markdown]
# ### 5th method. Self-play through MCTS

# %%
possible_moves=all_possible_moves()
model=tf.keras.models.load_model(r'C:\Users\45819\Downloads\supervised_model__.h5')

class TreeNode():
    def __init__(self,board):
        # average winrate of node
        self.M=0
        
        # amounts of wins
        self.W=0
        
        #amount of times this node has been visited
        self.V=0
        
        # Depth away from root
        self.depth=0
        
        # Variation name:
        self.variation=[]
        
        ### Each node should also have probabilities of being visited from previous position to be used for montecarlo
        self.Prior_Probability=0
        
        # Visited moves (at least one simulation has been done for that move)
        self.visitedMovesAndNodes=[]
        
        # Possible moves that have not been expanded
        self.nonVisitedLegalMoves=[]
        
        # the board
        self.board=board
        
        # The root node does not have any parents, for the creation of the children (moves), 
        # For the children upon creation we will modify the self.parent attribute
        self.parent=None
        
        for m in self.board.legal_moves:
            self.nonVisitedLegalMoves.append(m)
    #Is this a leaf node 
    def isMCTSLeafNode(self):
        return len(self.nonVisitedLegalMoves)!=0
    def isTerminalNode(self):
        return len(self.nonVisitedLegalMoves)==0 and len(self.visitedMovesAndNodes)==0

    
def get_network_probabilities(board):
    x=board_to_network_input(board)
    x=np.expand_dims(x, axis=0)
    # Predict move probabilities of the network
    probs,evaluation=model.predict(x)
    probs=probs.reshape(1968)
    legal_moves=[str(move) for move in list(board.legal_moves)]
    legal_moves_idxs = [i for i, x in enumerate(possible_moves) if x in legal_moves]
    mask=np.zeros_like(probs,dtype=bool)
    mask[legal_moves_idxs]=True
    probs[~mask]=0
    probs/=np.sum(probs)
    return probs
    
def Q_PLUS_U(node,parent):

    c_pukt=1
    P=node.Prior_Probability
    U=c_pukt*P*np.sqrt(parent.V)/(1+node.V)
    Q=node.M
    return Q+U



def select(node):
    #If the node is a leaf or a terminal node return the node itself.
    if node.isMCTSLeafNode() or node.isTerminalNode():
        print('selection has reached a leaf node')
        return node
    else:
        maxCUChild= None
        maxCUValue=-1000000

        for move, child in node.visitedMovesAndNodes:
            CUValChild=Q_PLUS_U(child,node)
            if (CUValChild>maxCUValue):
                maxCUChild=child
                maxCUValue=CUValChild
        if (maxCUChild==None):
            raise ValueError("could not identify child with best uct value")
        else:
            return (select(maxCUChild))

def expand(node):
    moveToExpand=node.nonVisitedLegalMoves.pop()
#     print('expanding move: ',moveToExpand)
    board= node.board.copy()
    probs=get_network_probabilities(board)
    
    idx=np.where(str(moveToExpand)==possible_moves)
    print('expanding move: ',str(moveToExpand))
    print('Normalized probability:',probs[idx][0])
    #Push the move on a new copied version of the board
    board.push(moveToExpand)
    childNode=TreeNode(board)
    childNode.parent=node
    childNode.Prior_Probability=probs[idx][0]
    childNode.depth=node.depth+1
    childNode.variation.append(str(moveToExpand))
    node.visitedMovesAndNodes.append((moveToExpand, childNode))
    return childNode
    
def simulate(node):
    board=node.board.copy()
    turn=board.turn
    moves=[]
    i=0
    ## Get the board of the node
    while((board.result()!= "1-0") and (board.result()!= "0-1") and (board.result()!= "1/2-1/2") ):
        
        probs=get_network_probabilities(board)
        idx=np.random.choice(len(probs),p=probs)
        print('MCTS simulation: move chosen:',possible_moves[idx])
        node.variation.append(possible_moves[idx])
        move=chess.Move.from_uci(possible_moves[idx])
        moves.append(move)
        board.push(move)
#         if i<10:
#             print(i+1,' move made:')
#             i+=1
#             print(board)
    payout=0.5
    o=board.result()
    print('moves played:',[str(move) for move in moves])
    if o=="1-0":
        payout=1
        print('white win')
    if o=="0-1":
        payout=0
        print('black win')
    if o=="1/2-1/2":
        payout=0.5
        print('its a draw')
    return payout



def backpropagate(node,payout):
    print('backpropagating a payout of ',payout,'for node with variation:',node.variation,'at depth', node.depth)
    node.M=((node.M*node.V)+payout)/(node.V+1)
    node.V=node.V+1
    node.W=node.W+payout
    print('updated node.M and node.V values:',node.M,node.V)
    if node.parent!=None:
        return backpropagate(node.parent,payout)
    

    
fen=   "r1bqkbnr/pppp1ppp/n7/4p3/2B1P3/5Q2/PPPP1PPP/RNB1K1NR w KQkq - 0 1"



def run_MCTS_step(fen,N_simulations):
    
    board=chess.Board(fen)
    root=TreeNode(board)

    for i in range(N_simulations):
        print('selection ',i,'is starting:')
        node=select(root)
        #if the selected node is a terminal we cannot expand
        # any child node. in this case, count htis as a win/draw/loss
        if (not node.isTerminalNode()):
    #         print('expansion ',i,'is starting:')
            node=expand(node)
            payout=simulate(node)
            backpropagate(node,payout)
        elif node.isTerminalNode():
            print('damn not terminal')

    #     print('simulation ',i,'is starting:')


    #     print('simulation result: ',payout)
    #     print('backpropagation ',i,'is starting:')


    root.visitedMovesAndNodes.sort(key=lambda x:x[1].M, reverse=True)
    return root
    
# root=run_MCTS_step(fen='8/8/2P5/1K6/8/8/8/k7 w - - 0 1',N_simulations=3)

# %%
def softmax(x):
    """Compute the softmax function for an array x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)


def set_network_probs(board,move):
    idx=np.where(possible_moves==moves)
    probs=np.zeros_like(possible_moves,dtype=np.float32)
    probs[idx]=1.
    # Update the move probabilities.
    return probs        
            
def print_results(root):
    i_w=0
    i_d=0
    i_l=0
    root.visitedMovesAndNodes.sort(key=lambda x:x[1].M, reverse=True)
    for m,child in root.visitedMovesAndNodes[0:200]:
        print(('move:',m.uci(),'mean win rate %f %%:'%(100*child.M),2*child.M-1,' amount of visits',child.V,'depth:',child.depth,'moveprobability:%2.2f%%'%(100*child.Prior_Probability),'variation:',child.variation[0]) )
        
#                 print('len=',child.visitedMovesAndNodes[0:40])
        if len(child.visitedMovesAndNodes)!=0:
            child.visitedMovesAndNodes.sort(key=lambda x:x[1].M, reverse=True)
            print_results(child)
        
        
import numpy as np

def mcts_results_to_nn_input(root):
    i_w = 0
    w_moves = []
    w_rates = []
    i_d = 0
    d_moves = []
    d_rates = []
    i_l = 0
    l_moves = []
    l_rates = []
    
    root.visitedMovesAndNodes.sort(key=lambda x:x[1].M, reverse=True)
    
    for m, child in root.visitedMovesAndNodes[:200]:
        win_rate = 2 * child.M - 1
        print(f'move: {m.uci()}, mean win rate {100*child.M:.2f}%, amount of visits: {child.V}, depth: {child.depth}')
        if child.M > 0.5:
            i_w += 1
            w_moves.append(m.uci())
            w_rates.append(child.M)
        elif child.M == 0.5:
            i_d += 1
            d_moves.append(m.uci())
            d_rates.append(child.M)
        elif child.M < 0.5:
            i_l += 1
            l_moves.append(m.uci())
            l_rates.append(max(child.M,1e-4))
    
    print(f'We have {i_w} winning, {i_d} drawing, and {i_l} losing moves.')
    print(f'Winning moves: {w_moves}\nDrawing moves: {d_moves}\nLosing moves: {l_moves}')
    
    if len(w_moves) != 0:
        moves, rates = w_moves, w_rates
    elif len(d_moves) != 0:
        moves, rates = d_moves, d_rates
    elif len(l_moves) != 0:
        moves, rates = l_moves, l_rates
        
    indices = [np.where(possible_moves == elem)[0][0] for elem in moves if elem in possible_moves]
    probs = np.zeros_like(possible_moves, dtype=np.float32)
    evaluations=np.zeros_like(probs)
    for j, index in enumerate(indices):
        print(rates[j])
        probs[index] = rates[j]
        evaluations[index]=2*rates[j]-1
        
    print(np.sum(probs))
    probs/=np.sum(probs)
#     probs=softmax(probs)
    
    
    
    
    
    return probs,evaluations
    
    
# mcts_results_to_nn_input(root)

# %%
def play_n_MCTS_games(games=3, save=False, N_simulations=3):
    """
    Play a given number of games of chess and save the positions, best move probabilities,
    outcomes, and evaluations of each move in separate files if save is True.
    
    Parameters:
        games (int): The number of games to play.
        save (bool): If True, save the data generated from each game in separate files.
        N_simulations (int): The number of simulations to run in MCTS.
    """
    
    # Loop over each game
    for game in range(games):
        
        # Initialize the board object and set the starting position
        b = Chess_object()
        b.setstartingposition()
        
        i = 0
        
        # If saving, set the output images folder location
        if save:
            x = len(choose_files_with_pattern(max_num=9999, pickles_path='./supervised_game*')) + 2
            formatted_string = "{:03d}".format(x)
            game_folder = './supervised_game' + formatted_string
            if not os.path.isdir(game_folder):
                os.mkdir(game_folder)
            
        # Initialize the placeholders for the saved training data    
        positions = []
        best_moves_probs = []
        outcomes = []
        evaluations = []
        
        # Loop until the game is over
        while True:
            
            # Run Monte Carlo Simulations
            fen = b.board.fen()
            mcts_results = run_MCTS_step(fen=fen, N_simulations=N_simulations)
            probs, mean_outcomes = mcts_results_to_nn_input(mcts_results)
            x = b.toNetworkInput()
            
          
            # Get the move to play
            idx = np.random.choice(len(probs), p=probs)
            evaluation = mean_outcomes[idx]
            print('according to MCTS we have an evaluation of:', evaluation, 'for the randomly chosen move:', possible_moves[idx])
            
            # Find the string representation of the best move (for example 'e2e4')
            bm = b.find_index_move(idx)
            
            # Print the move probability and the best move
            print('%2.2f'%(probs[idx]/np.sum(probs)*100),'%% move probability')
            print(bm)
            
            # Save the data for the current move
            if i==0:
                positions=np.copy(x)
                best_moves_probs.append(probs)
                evaluations.append(0)
            else:    
                positions=np.concatenate((positions,x),axis=0)
                evaluations.append(evaluation_last)
                best_moves_probs.append(probs)
            
            evaluation_last=evaluation
            # Make the move!
            b.applymove(bm)
            if save:
                save_image(b.board,i,formatted_string)
            i+=1
            
            condition,score= b.isTerminal()
            if condition:
                print('game is over', score)
                break
        print('game lasted ',i,' moves \n\n\n')
        
        x=len(choose_files_with_pattern(max_num=9999, pickles_path='./selfplaydata/positions*'))+1
        formatted_string = "{:05d}".format(x)
        
        with open("./selfplaydata/positions"+formatted_string, "ab") as f:
            # Dump the new data to the file using pickle
            pickle.dump(positions, f)
        with open("./selfplaydata/best_moves_probs"+formatted_string, "ab") as f:
            # Dump the new data to the file using pickle
            pickle.dump(best_moves_probs, f)
        with open("./selfplaydata/evaluations"+formatted_string, "ab") as f:
            # Dump the new data to the file using pickle
            pickle.dump(evaluations, f)
        print('score:',score)
        for k in range(i):
            outcomes.append(score)
        with open("./selfplaydata/outcomes"+formatted_string,"ab") as f:
            pickle.dump(outcomes,f)
play_n_MCTS_games(games=1,save=True,N_simulations=50)
# Out:
# selection  0 is starting:
# selection has reached a leaf node
# 1/1 [==============================] - 0s 261ms/step
# expanding move:  a2a4
# Normalized probability: 0.00056511274
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: d7d5
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: d2d4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c8f5
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: c1f4
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: e7e6
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: e2e3
# 1/1 [==============================] - 0s 23ms/step
# MCTS simulation: move chosen: f8b4
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: c2c3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: b4a5
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: b2b4
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: a5b6
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: g1f3
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: c7c6
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: b1d2
# 1/1 [==============================] - 0s 24ms/step
# MCTS simulation: move chosen: g8f6
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: f3e5
# 1/1 [==============================] - 0s 24ms/step
# MCTS simulation: move chosen: e8g8
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: f1e2
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: b6c7
# 1/1 [==============================] - 0s 23ms/step
# MCTS simulation: move chosen: f4g3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: f6e4
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: d2e4
# 1/1 [==============================] - 0s 23ms/step
# MCTS simulation: move chosen: f5e4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e2f3
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: c7e5
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: g3e5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d8g5
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: f3e4
# 1/1 [==============================] - 0s 28ms/step
# MCTS simulation: move chosen: d5e4
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: e1g1
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: b8d7
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: e5d6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: f8d8
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: d1c2
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: g5g4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: h2h3
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: g4f5
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: c3c4
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: b7b6
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: a4a5
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: b6b5
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: c4c5
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: a7a6
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: f2f3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e4f3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c2f5
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: e6f5
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: f1f3
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: g7g6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: a1f1
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d7f6
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: d6e7
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: f6e4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e7d8
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: e4d2
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: d8f6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d2f3
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: f1f3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: a8e8
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: g2g4
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: f5g4
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: h3g4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: h7h6
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: g1f2
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: g8h7
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: g4g5
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: h6g5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: f3h3
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: h7g8
# 1/1 [==============================] - 0s 23ms/step
# MCTS simulation: move chosen: h3h4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: g5h4
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: f6e5
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: h4h3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e5f6
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: g8h7
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e3e4
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: e8e4
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: d4d5
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: c6d5
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: c5c6
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: e4h4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c6c7
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d5d4
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: c7c8q
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: h3h2
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c8d7
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: h4g4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d7f7
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: h7h6
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: f7c7
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: g6g5
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: c7h2
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: h6g6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: h2h1
# 1/1 [==============================] - 0s 23ms/step
# MCTS simulation: move chosen: g4f4
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: f2g3
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: g6f6
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: h1e1
# 1/1 [==============================] - 0s 23ms/step
# MCTS simulation: move chosen: f4f5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e1d2
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: f6e6
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: d2d4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e6e7
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: d4d1
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: f5f4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d1d5
# 1/1 [==============================] - 0s 23ms/step
# MCTS simulation: move chosen: e7f6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d5d7
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: f4f5
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: d7d6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: f6g7
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: d6d5
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: f5d5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: g3f3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: g7g6
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: f3g3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d5e5
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: g3g4
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: e5f5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: g4g3
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: f5f3
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: g3f3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: g6f5
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: f3g3
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: f5e5
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: g3g4
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: e5e4
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: g4g5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e4f3
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: g5h5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: f3f4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: h5h4
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: f4e4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: h4h3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e4f3
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: h3h4
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: f3f4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: h4h3
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: f4f5
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: h3h4
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: f5f6
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: h4h5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: f6e6
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: h5h6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e6f6
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: h6h5
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: f6e6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: h5h6
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: e6e5
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: h6h7
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: e5e6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: h7h8
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: e6d7
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: h8g7
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d7d6
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: g7f7
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d6d5
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: f7e7
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: d5c4
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: e7d7
# 1/1 [==============================] - 0s 23ms/step
# MCTS simulation: move chosen: c4b4
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: d7e6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: b4c4
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: e6d6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c4d3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d6d5
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: d3c3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d5c5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c3b3
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: c5b6
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: b3c4
# 1/1 [==============================] - 0s 24ms/step
# MCTS simulation: move chosen: b6c6
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: c4d3
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: c6b6
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: d3c4
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: b6c6
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: c4d3
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: c6b6
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: d3e2
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: b6c5
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: e2d3
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: c5d5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d3c3
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: d5c5
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: c3d3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c5d5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d3c3
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: d5c5
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: c3b3
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: c5b6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: b3c4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: b6c6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c4d3
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: c6b6
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: d3e2
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: b6c5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e2d3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c5d5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d3c3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d5c5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c3d3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c5d5
# moves played: ['d7d5', 'd2d4', 'c8f5', 'c1f4', 'e7e6', 'e2e3', 'f8b4', 'c2c3', 'b4a5', 'b2b4', 'a5b6', 'g1f3', 'c7c6', 'b1d2', 'g8f6', 'f3e5', 'e8g8', 'f1e2', 'b6c7', 'f4g3', 'f6e4', 'd2e4', 'f5e4', 'e2f3', 'c7e5', 'g3e5', 'd8g5', 'f3e4', 'd5e4', 'e1g1', 'b8d7', 'e5d6', 'f8d8', 'd1c2', 'g5g4', 'h2h3', 'g4f5', 'c3c4', 'b7b6', 'a4a5', 'b6b5', 'c4c5', 'a7a6', 'f2f3', 'e4f3', 'c2f5', 'e6f5', 'f1f3', 'g7g6', 'a1f1', 'd7f6', 'd6e7', 'f6e4', 'e7d8', 'e4d2', 'd8f6', 'd2f3', 'f1f3', 'a8e8', 'g2g4', 'f5g4', 'h3g4', 'h7h6', 'g1f2', 'g8h7', 'g4g5', 'h6g5', 'f3h3', 'h7g8', 'h3h4', 'g5h4', 'f6e5', 'h4h3', 'e5f6', 'g8h7', 'e3e4', 'e8e4', 'd4d5', 'c6d5', 'c5c6', 'e4h4', 'c6c7', 'd5d4', 'c7c8q', 'h3h2', 'c8d7', 'h4g4', 'd7f7', 'h7h6', 'f7c7', 'g6g5', 'c7h2', 'h6g6', 'h2h1', 'g4f4', 'f2g3', 'g6f6', 'h1e1', 'f4f5', 'e1d2', 'f6e6', 'd2d4', 'e6e7', 'd4d1', 'f5f4', 'd1d5', 'e7f6', 'd5d7', 'f4f5', 'd7d6', 'f6g7', 'd6d5', 'f5d5', 'g3f3', 'g7g6', 'f3g3', 'd5e5', 'g3g4', 'e5f5', 'g4g3', 'f5f3', 'g3f3', 'g6f5', 'f3g3', 'f5e5', 'g3g4', 'e5e4', 'g4g5', 'e4f3', 'g5h5', 'f3f4', 'h5h4', 'f4e4', 'h4h3', 'e4f3', 'h3h4', 'f3f4', 'h4h3', 'f4f5', 'h3h4', 'f5f6', 'h4h5', 'f6e6', 'h5h6', 'e6f6', 'h6h5', 'f6e6', 'h5h6', 'e6e5', 'h6h7', 'e5e6', 'h7h8', 'e6d7', 'h8g7', 'd7d6', 'g7f7', 'd6d5', 'f7e7', 'd5c4', 'e7d7', 'c4b4', 'd7e6', 'b4c4', 'e6d6', 'c4d3', 'd6d5', 'd3c3', 'd5c5', 'c3b3', 'c5b6', 'b3c4', 'b6c6', 'c4d3', 'c6b6', 'd3c4', 'b6c6', 'c4d3', 'c6b6', 'd3e2', 'b6c5', 'e2d3', 'c5d5', 'd3c3', 'd5c5', 'c3d3', 'c5d5', 'd3c3', 'd5c5', 'c3b3', 'c5b6', 'b3c4', 'b6c6', 'c4d3', 'c6b6', 'd3e2', 'b6c5', 'e2d3', 'c5d5', 'd3c3', 'd5c5', 'c3d3', 'c5d5']
# its a draw
# backpropagating a payout of  0.5 for node with variation: ['a2a4', 'd7d5', 'd2d4', 'c8f5', 'c1f4', 'e7e6', 'e2e3', 'f8b4', 'c2c3', 'b4a5', 'b2b4', 'a5b6', 'g1f3', 'c7c6', 'b1d2', 'g8f6', 'f3e5', 'e8g8', 'f1e2', 'b6c7', 'f4g3', 'f6e4', 'd2e4', 'f5e4', 'e2f3', 'c7e5', 'g3e5', 'd8g5', 'f3e4', 'd5e4', 'e1g1', 'b8d7', 'e5d6', 'f8d8', 'd1c2', 'g5g4', 'h2h3', 'g4f5', 'c3c4', 'b7b6', 'a4a5', 'b6b5', 'c4c5', 'a7a6', 'f2f3', 'e4f3', 'c2f5', 'e6f5', 'f1f3', 'g7g6', 'a1f1', 'd7f6', 'd6e7', 'f6e4', 'e7d8', 'e4d2', 'd8f6', 'd2f3', 'f1f3', 'a8e8', 'g2g4', 'f5g4', 'h3g4', 'h7h6', 'g1f2', 'g8h7', 'g4g5', 'h6g5', 'f3h3', 'h7g8', 'h3h4', 'g5h4', 'f6e5', 'h4h3', 'e5f6', 'g8h7', 'e3e4', 'e8e4', 'd4d5', 'c6d5', 'c5c6', 'e4h4', 'c6c7', 'd5d4', 'c7c8q', 'h3h2', 'c8d7', 'h4g4', 'd7f7', 'h7h6', 'f7c7', 'g6g5', 'c7h2', 'h6g6', 'h2h1', 'g4f4', 'f2g3', 'g6f6', 'h1e1', 'f4f5', 'e1d2', 'f6e6', 'd2d4', 'e6e7', 'd4d1', 'f5f4', 'd1d5', 'e7f6', 'd5d7', 'f4f5', 'd7d6', 'f6g7', 'd6d5', 'f5d5', 'g3f3', 'g7g6', 'f3g3', 'd5e5', 'g3g4', 'e5f5', 'g4g3', 'f5f3', 'g3f3', 'g6f5', 'f3g3', 'f5e5', 'g3g4', 'e5e4', 'g4g5', 'e4f3', 'g5h5', 'f3f4', 'h5h4', 'f4e4', 'h4h3', 'e4f3', 'h3h4', 'f3f4', 'h4h3', 'f4f5', 'h3h4', 'f5f6', 'h4h5', 'f6e6', 'h5h6', 'e6f6', 'h6h5', 'f6e6', 'h5h6', 'e6e5', 'h6h7', 'e5e6', 'h7h8', 'e6d7', 'h8g7', 'd7d6', 'g7f7', 'd6d5', 'f7e7', 'd5c4', 'e7d7', 'c4b4', 'd7e6', 'b4c4', 'e6d6', 'c4d3', 'd6d5', 'd3c3', 'd5c5', 'c3b3', 'c5b6', 'b3c4', 'b6c6', 'c4d3', 'c6b6', 'd3c4', 'b6c6', 'c4d3', 'c6b6', 'd3e2', 'b6c5', 'e2d3', 'c5d5', 'd3c3', 'd5c5', 'c3d3', 'c5d5', 'd3c3', 'd5c5', 'c3b3', 'c5b6', 'b3c4', 'b6c6', 'c4d3', 'c6b6', 'd3e2', 'b6c5', 'e2d3', 'c5d5', 'd3c3', 'd5c5', 'c3d3', 'c5d5'] at depth 1
# updated node.M and node.V values: 0.5 1
# backpropagating a payout of  0.5 for node with variation: [] at depth 0
# updated node.M and node.V values: 0.5 1
# selection  1 is starting:
# selection has reached a leaf node
# 1/1 [==============================] - 0s 19ms/step
# expanding move:  b2b4
# Normalized probability: 0.0012046176
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e7e5
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: c1b2
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e5e4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e2e3
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: d7d5
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: a2a3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: g8f6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d2d3
# 1/1 [==============================] - 0s 26ms/step
# MCTS simulation: move chosen: c8f5
# 1/1 [==============================] - 0s 24ms/step
# MCTS simulation: move chosen: d3e4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: f5e4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: b1c3
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: c7c5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c3e4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: f6e4
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: b4c5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: f8c5
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: b2g7
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: h8g8
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: g7d4
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: c5d4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e3d4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e4f2
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: d1e2
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: f2e4
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: e2d3
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: h7h6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: g1f3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: b8c6
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: c2c3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d8e7
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e1c1
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e8c8
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c1b2
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e4f2
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d3f5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c8b8
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: f1a6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: b7a6
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: h1e1
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: f2d1
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: b2a2
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: g8g2
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: a2b3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c6a5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: b3a4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e7b7
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: f3d2
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: d1b2
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: a4a5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: g2g4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: f5f4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: g4f4
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: e1e3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: b7b3
# 1/1 [==============================] - 0s 21ms/step
# MCTS simulation: move chosen: d2f3
# 1/1 [==============================] - 0s 25ms/step
# MCTS simulation: move chosen: b3c4
# 1/1 [==============================] - 0s 22ms/step
# MCTS simulation: move chosen: f3e5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: f4d4
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: c3d4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c4a2
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: a3a4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: f7f6
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e5d3
# 1/1 [==============================] - 0s 23ms/step
# MCTS simulation: move chosen: b2c4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: a5b4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: c4e3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: d3c5
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: e3g4
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: h2h3
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: g4e3
# 1/1 [==============================] - 0s 18ms/step
# MCTS simulation: move chosen: c5d3
# 1/1 [==============================] - 0s 19ms/step
# MCTS simulation: move chosen: a2a3
# 1/1 [==============================] - 0s 20ms/step
# MCTS simulation: move chosen: b4a3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 97
#      95         with open("./selfplaydata/outcomes"+formatted_string,"ab") as f:
#      96             pickle.dump(outcomes,f)
# ---> 97 play_n_MCTS_games(games=1,save=True,N_simulations=50)
#
# Cell In[5], line 40, in play_n_MCTS_games(games, save, N_simulations)
#      36 while True:
#      37
#      38     # Run Monte Carlo Simulations
#      39     fen = b.board.fen()
# ---> 40     mcts_results = run_MCTS_step(fen=fen, N_simulations=N_simulations)
#      41     probs, mean_outcomes = mcts_results_to_nn_input(mcts_results)
#      42     x = b.toNetworkInput()
#
# Cell In[3], line 171, in run_MCTS_step(fen, N_simulations)
#     168     if (not node.isTerminalNode()):
#     169 #         print('expansion ',i,'is starting:')
#     170         node=expand(node)
# --> 171         payout=simulate(node)
#     172         backpropagate(node,payout)
#     173     elif node.isTerminalNode():
#
# Cell In[3], line 116, in simulate(node)
#     113 ## Get the board of the node
#     114 while((board.result()!= "1-0") and (board.result()!= "0-1") and (board.result()!= "1/2-1/2") ):
# --> 116     probs=get_network_probabilities(board)
#     117     idx=np.random.choice(len(probs),p=probs)
#     118     print('MCTS simulation: move chosen:',possible_moves[idx])
#
# Cell In[3], line 50, in get_network_probabilities(board)
#      48 x=np.expand_dims(x, axis=0)
#      49 # Predict move probabilities of the network
# ---> 50 probs,evaluation=model.predict(x)
#      51 probs=probs.reshape(1968)
#      52 legal_moves=[str(move) for move in list(board.legal_moves)]
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\training.py:2350, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2348 for step in data_handler.steps():
#    2349     callbacks.on_predict_batch_begin(step)
# -> 2350     tmp_batch_outputs = self.predict_function(iterator)
#    2351     if data_handler.should_sync:
#    2352         context.async_wait()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:880, in Function.__call__(self, *args, **kwds)
#     877 compiler = "xla" if self._jit_compile else "nonXla"
#     879 with OptionalXlaContext(self._jit_compile):
# --> 880   result = self._call(*args, **kwds)
#     882 new_tracing_count = self.experimental_get_tracing_count()
#     883 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:919, in Function._call(self, *args, **kwds)
#     916 self._lock.release()
#     917 # In this case we have not created variables on the first call. So we can
#     918 # run the first trace but we should fail if variables are created.
# --> 919 results = self._variable_creation_fn(*args, **kwds)
#     920 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     921   raise ValueError("Creating variables on a non-first call to a function"
#     922                    " decorated with tf.function.")
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:134, in TracingCompiler.__call__(self, *args, **kwargs)
#     131 with self._lock:
#     132   (concrete_function,
#     133    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134 return concrete_function._call_flat(
#     135     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1745, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1741 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1742 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1743     and executing_eagerly):
#    1744   # No tape is watching; skip to running the function.
# -> 1745   return self._build_call_outputs(self._inference_function.call(
#    1746       ctx, args, cancellation_manager=cancellation_manager))
#    1747 forward_backward = self._select_forward_and_backward_functions(
#    1748     args,
#    1749     possible_gradient_type,
#    1750     executing_eagerly)
#    1751 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:378, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     376 with _InterpolateFunctionError(self):
#     377   if cancellation_manager is None:
# --> 378     outputs = execute.execute(
#     379         str(self.signature.name),
#     380         num_outputs=self._num_outputs,
#     381         inputs=args,
#     382         attrs=attrs,
#     383         ctx=ctx)
#     384   else:
#     385     outputs = execute.execute_with_cancellation(
#     386         str(self.signature.name),
#     387         num_outputs=self._num_outputs,
#    (...)
#     390         ctx=ctx,
#     391         cancellation_manager=cancellation_manager)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:
